# %%
# Imports
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import joblib
import random
import pickle
import numpy as np
from statistics import mean, stdev
from sklearn.metrics import roc_auc_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import RepeatedStratifiedKFold
import config

# %%
# --------------------------
# Set seeds for reproducibility
# --------------------------
SEED = 100
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
g = torch.Generator()
g.manual_seed(SEED)


# --------------------------
# Hyperparameters: (for my own reference)
# --------------------------
# lr (learning rate)
# batch size 32
# hidden_dim
# number_of_epochs 
# patience

# =======================
# Custom Dataset
# =======================
class MultimodalDataset(Dataset):
    def __init__(self, clin_path, mrna_path, mut_path, labels_path):
        # Load preprocessed data
        self.clinical = joblib.load(clin_path).to_numpy().astype(float)
        self.mrna = joblib.load(mrna_path).to_numpy().astype(float)
        self.mutation = joblib.load(mut_path).to_numpy().astype(float)
        self.labels = joblib.load(labels_path).to_numpy().astype(float)
        print(self.clinical.shape)
        print(self.mrna.shape)
        print(self.mutation.shape)
                
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return (
            torch.tensor(self.clinical[idx], dtype=torch.float32),
            torch.tensor(self.mrna[idx], dtype=torch.float32),
            torch.tensor(self.mutation[idx], dtype=torch.float32),
            torch.tensor(self.labels[idx], dtype=torch.float32)
        )

# =======================
# Paths
# =======================
base_dir = "../preprocessed_data/some_feature_selection"

train_dataset = MultimodalDataset(
    f"{base_dir}/train/clinical.pkl",
    f"{base_dir}/train/mrna.pkl",
    f"{base_dir}/train/mutation.pkl",
    f"{base_dir}/train/labels.pkl"
)
# FIXME TESTING CHANGED VAL AND TEST
val_dataset = MultimodalDataset(
    f"{base_dir}/val/clinical.pkl",
    f"{base_dir}/val/mrna.pkl",
    f"{base_dir}/val/mutation.pkl",
    f"{base_dir}/val/labels.pkl"
)

test_dataset = MultimodalDataset(
    f"{base_dir}/test/clinical.pkl",
    f"{base_dir}/test/mrna.pkl",
    f"{base_dir}/test/mutation.pkl",
    f"{base_dir}/test/labels.pkl"
)


train_loader = DataLoader(
    train_dataset,
    batch_size=config.BATCH_SIZE,
    shuffle=True,
    generator=g,
    worker_init_fn=lambda _: np.random.seed(SEED),
    pin_memory=True,  
)

val_loader = DataLoader(
    val_dataset,
    batch_size=config.BATCH_SIZE,
    generator=g,
    worker_init_fn=lambda _: np.random.seed(SEED),
    pin_memory=True,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=config.BATCH_SIZE,
    generator=g,
    worker_init_fn=lambda _: np.random.seed(SEED),
    pin_memory=True,
)

# =======================
# Simple Neural Network
# =======================
class SimpleMultimodalNet(nn.Module):
    def __init__(self, clin_dim, mrna_dim, mut_dim, hidden_dim=config.HIDDEN_DIM, dropout=config.DROPOUT, lr=config.LEARNING_RATE):
        super().__init__()

        # Separate encoders for each modality
        self.clinical_fc = nn.Sequential(
            nn.Linear(clin_dim, hidden_dim), 
            nn.ReLU(),
            nn.Dropout(dropout)
            )
        self.mrna_fc = nn.Sequential(
            nn.Linear(mrna_dim, hidden_dim), 
            nn.ReLU(),
            nn.Dropout(dropout)
            )
        self.mut_fc = nn.Sequential(
            nn.Linear(mut_dim, hidden_dim), 
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        
        # Fusion layer
        self.fusion_fc = nn.Sequential(
            nn.Linear(hidden_dim * 3, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1),  # Binary output
        )
        
    def forward(self, clin, mrna, mut):
        clin_emb = self.clinical_fc(clin)
        mrna_emb = self.mrna_fc(mrna)
        mut_emb = self.mut_fc(mut)
        
        # Concatenate embeddings
        fused = torch.cat([clin_emb, mrna_emb, mut_emb], dim=1)
        output = self.fusion_fc(fused)
        return output.squeeze()
# Out:
# (316, 31)
# (316, 669)
# (316, 411)
# (68, 31)
# (68, 669)
# (68, 411)
# (68, 31)
# (68, 669)
# (68, 411)

# %%
# =======================
# Initialize Model
# =======================
# Use one batch to get dimensions
sample_batch = next(iter(train_loader))
clin_dim = sample_batch[0].shape[1]
mrna_dim = sample_batch[1].shape[1]
mut_dim = sample_batch[2].shape[1]

# =======================
# Loss and Optimizer
# =======================
# Convert to tensor and move to the same device as model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleMultimodalNet(clin_dim, mrna_dim, mut_dim).to(device)

# Compute pos_weight
num_pos = (train_dataset.labels == 1).sum()
num_neg = (train_dataset.labels == 0).sum()
pos_weight_val = num_neg / num_pos
pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32, device=device)

# Initialize loss
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = torch.optim.Adam(model.parameters(), lr=config.LEARNING_RATE)

# --------------------------
# Training loop with validation metrics
# --------------------------
best_auroc = 0
counter = 0

for epoch in range(config.NUM_EPOCHS):
    model.train()
    train_losses = []

    for clin, mrna, mut, labels in train_loader:
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()
        
        optimizer.zero_grad()
        outputs = model(clin, mrna, mut)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    avg_train_loss = sum(train_losses) / len(train_losses)

    # --- Validation ---
    model.eval()
    val_losses = []
    all_labels = []
    all_preds = []
    
    with torch.no_grad():
        for clin, mrna, mut, labels in val_loader:
            clin = clin.to(device, non_blocking=True)
            mrna = mrna.to(device, non_blocking=True)
            mut = mut.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True).float()
    
            outputs = model(clin, mrna, mut)
            val_loss = criterion(outputs, labels)
            val_losses.append(val_loss.item())
    
            # collect true labels and sigmoid probabilities (on CPU)
            all_labels.append(labels.detach().cpu())
            all_preds.append(torch.sigmoid(outputs).detach().cpu())

    avg_val_loss = sum(val_losses) / len(val_losses)
    all_labels = torch.cat(all_labels)
    all_preds = torch.cat(all_preds)

    # Binarize predictions at 0.5 threshold
    pred_labels = (all_preds >= 0.5).float()

    val_auroc = roc_auc_score(all_labels.numpy(), all_preds.numpy())
    val_precision = precision_score(all_labels.numpy(), pred_labels.numpy(), zero_division=0)
    val_recall = recall_score(all_labels.numpy(), pred_labels.numpy(), zero_division=0)
    val_f1 = f1_score(all_labels.numpy(), pred_labels.numpy(), zero_division=0)

    print(f"Epoch {epoch+1} - "
          f"Train Loss: {avg_train_loss:.4f}, "
          f"Val Loss: {avg_val_loss:.4f}, "
          f"AUROC: {val_auroc:.4f}, "
          f"Precision: {val_precision:.4f}, "
          f"Recall: {val_recall:.4f}, "
          f"F1: {val_f1:.4f}")

    # --- Early stopping based on AUROC ---
    if val_auroc >= best_auroc:
        best_auroc = val_auroc
        counter = 0
        # Optionally save best model
        torch.save(model.state_dict(), "best_model.pth")
    else:
        counter += 1
        if counter >= config.PATIENCE:
            print(f"Early stopping at epoch {epoch+1} with patience of {config.PATIENCE}")
            break
# Out:
# Epoch 1 - Train Loss: 115.2585, Val Loss: 1.8183, AUROC: 0.6280, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 2 - Train Loss: 144.8012, Val Loss: 12.4456, AUROC: 0.4000, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 3 - Train Loss: 139.2983, Val Loss: 15.0209, AUROC: 0.5483, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 4 - Train Loss: 125.1492, Val Loss: 17.0629, AUROC: 0.5364, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 5 - Train Loss: 129.1206, Val Loss: 13.6245, AUROC: 0.6238, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 6 - Train Loss: 110.3296, Val Loss: 5.7563, AUROC: 0.6308, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 7 - Train Loss: 121.5931, Val Loss: 4.5079, AUROC: 0.6797, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 8 - Train Loss: 118.9109, Val Loss: 17.5161, AUROC: 0.5273, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 9 - Train Loss: 103.6218, Val Loss: 13.8816, AUROC: 0.5629, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 10 - Train Loss: 108.0980, Val Loss: 11.6793, AUROC: 0.6755, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 11 - Train Loss: 102.2011, Val Loss: 10.0533, AUROC: 0.6399, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 12 - Train Loss: 82.9195, Val Loss: 4.9906, AUROC: 0.7608, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 13 - Train Loss: 126.1544, Val Loss: 8.8248, AUROC: 0.7063, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 14 - Train Loss: 82.4329, Val Loss: 7.0583, AUROC: 0.6769, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 15 - Train Loss: 88.2915, Val Loss: 11.2667, AUROC: 0.6888, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 16 - Train Loss: 90.3579, Val Loss: 8.5795, AUROC: 0.7140, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 17 - Train Loss: 72.5946, Val Loss: 14.2807, AUROC: 0.6343, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 18 - Train Loss: 100.9471, Val Loss: 15.8406, AUROC: 0.5727, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 19 - Train Loss: 81.0808, Val Loss: 19.8806, AUROC: 0.5182, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 20 - Train Loss: 86.1256, Val Loss: 23.5671, AUROC: 0.5091, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 21 - Train Loss: 91.1232, Val Loss: 20.1383, AUROC: 0.5273, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 22 - Train Loss: 81.0228, Val Loss: 12.9502, AUROC: 0.6797, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 23 - Train Loss: 76.2448, Val Loss: 17.2282, AUROC: 0.5545, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 24 - Train Loss: 69.6721, Val Loss: 15.0637, AUROC: 0.5944, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 25 - Train Loss: 60.1362, Val Loss: 8.6401, AUROC: 0.7545, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 26 - Train Loss: 68.2958, Val Loss: 7.3600, AUROC: 0.7664, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 27 - Train Loss: 70.0125, Val Loss: 5.6884, AUROC: 0.7818, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 28 - Train Loss: 59.2184, Val Loss: 10.2783, AUROC: 0.7538, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 29 - Train Loss: 67.2969, Val Loss: 9.8017, AUROC: 0.7531, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 30 - Train Loss: 62.1866, Val Loss: 14.8113, AUROC: 0.5958, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 31 - Train Loss: 51.4567, Val Loss: 17.4613, AUROC: 0.5727, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 32 - Train Loss: 53.8433, Val Loss: 19.7942, AUROC: 0.5636, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 33 - Train Loss: 57.4050, Val Loss: 19.4185, AUROC: 0.5727, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 34 - Train Loss: 57.2281, Val Loss: 15.8507, AUROC: 0.6308, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 35 - Train Loss: 47.1857, Val Loss: 13.6060, AUROC: 0.6517, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 36 - Train Loss: 51.9422, Val Loss: 8.3525, AUROC: 0.7070, Precision: 0.1970, Recall: 1.0000, F1: 0.3291
# Epoch 37 - Train Loss: 40.6397, Val Loss: 12.3900, AUROC: 0.6503, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 38 - Train Loss: 44.9838, Val Loss: 14.5223, AUROC: 0.6566, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 39 - Train Loss: 39.2815, Val Loss: 13.7127, AUROC: 0.6434, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 40 - Train Loss: 51.9335, Val Loss: 12.4648, AUROC: 0.6706, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 41 - Train Loss: 39.8877, Val Loss: 11.4368, AUROC: 0.6986, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 42 - Train Loss: 41.9035, Val Loss: 9.0508, AUROC: 0.7357, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 43 - Train Loss: 38.7102, Val Loss: 6.7510, AUROC: 0.7538, Precision: 0.2000, Recall: 1.0000, F1: 0.3333
# Epoch 44 - Train Loss: 36.1423, Val Loss: 11.5603, AUROC: 0.7049, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 45 - Train Loss: 40.4371, Val Loss: 14.1692, AUROC: 0.6755, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 46 - Train Loss: 45.6087, Val Loss: 13.3902, AUROC: 0.6804, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 47 - Train Loss: 37.8032, Val Loss: 10.3168, AUROC: 0.7448, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 48 - Train Loss: 34.0839, Val Loss: 8.5177, AUROC: 0.7497, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 49 - Train Loss: 40.7610, Val Loss: 6.4745, AUROC: 0.7510, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 50 - Train Loss: 34.6711, Val Loss: 6.7431, AUROC: 0.7559, Precision: 0.1940, Recall: 1.0000, F1: 0.3250
# Epoch 51 - Train Loss: 23.4482, Val Loss: 3.8055, AUROC: 0.7860, Precision: 0.2063, Recall: 1.0000, F1: 0.3421
# Epoch 52 - Train Loss: 35.3237, Val Loss: 2.4564, AUROC: 0.7986, Precision: 0.2281, Recall: 1.0000, F1: 0.3714
# Epoch 53 - Train Loss: 36.1447, Val Loss: 3.8437, AUROC: 0.7930, Precision: 0.2097, Recall: 1.0000, F1: 0.3467
# Epoch 54 - Train Loss: 31.0853, Val Loss: 5.7017, AUROC: 0.7636, Precision: 0.1940, Recall: 1.0000, F1: 0.3250
# Epoch 55 - Train Loss: 30.9729, Val Loss: 4.9096, AUROC: 0.7664, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 56 - Train Loss: 24.5992, Val Loss: 3.7245, AUROC: 0.7790, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 57 - Train Loss: 36.2169, Val Loss: 4.6079, AUROC: 0.7664, Precision: 0.1940, Recall: 1.0000, F1: 0.3250
# Epoch 58 - Train Loss: 28.2661, Val Loss: 4.3783, AUROC: 0.7650, Precision: 0.1912, Recall: 1.0000, F1: 0.3210
# Epoch 59 - Train Loss: 23.4401, Val Loss: 3.4452, AUROC: 0.7720, Precision: 0.1940, Recall: 1.0000, F1: 0.3250
# Epoch 60 - Train Loss: 20.8965, Val Loss: 2.4139, AUROC: 0.7916, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 61 - Train Loss: 28.5810, Val Loss: 2.2431, AUROC: 0.8042, Precision: 0.2097, Recall: 1.0000, F1: 0.3467
# Epoch 62 - Train Loss: 28.4911, Val Loss: 2.4995, AUROC: 0.7832, Precision: 0.2031, Recall: 1.0000, F1: 0.3377
# Epoch 63 - Train Loss: 22.6578, Val Loss: 3.4467, AUROC: 0.7678, Precision: 0.1940, Recall: 1.0000, F1: 0.3250
# Epoch 64 - Train Loss: 24.9355, Val Loss: 2.9702, AUROC: 0.7762, Precision: 0.1970, Recall: 1.0000, F1: 0.3291
# Epoch 65 - Train Loss: 26.5568, Val Loss: 3.0886, AUROC: 0.7958, Precision: 0.2000, Recall: 1.0000, F1: 0.3333
# Epoch 66 - Train Loss: 22.3764, Val Loss: 2.1077, AUROC: 0.8014, Precision: 0.2097, Recall: 1.0000, F1: 0.3467
# Epoch 67 - Train Loss: 23.2399, Val Loss: 1.5005, AUROC: 0.7986, Precision: 0.2364, Recall: 1.0000, F1: 0.3824
# Epoch 68 - Train Loss: 18.3529, Val Loss: 1.2072, AUROC: 0.7972, Precision: 0.2821, Recall: 0.8462, F1: 0.4231
# Epoch 69 - Train Loss: 23.5009, Val Loss: 1.1154, AUROC: 0.7986, Precision: 0.2973, Recall: 0.8462, F1: 0.4400
# Epoch 70 - Train Loss: 19.1720, Val Loss: 1.2572, AUROC: 0.7888, Precision: 0.2727, Recall: 0.9231, F1: 0.4211
# Epoch 71 - Train Loss: 19.7913, Val Loss: 1.1210, AUROC: 0.7958, Precision: 0.2821, Recall: 0.8462, F1: 0.4231
# Epoch 72 - Train Loss: 15.5152, Val Loss: 1.0971, AUROC: 0.8028, Precision: 0.3793, Recall: 0.8462, F1: 0.5238
# Epoch 73 - Train Loss: 21.9524, Val Loss: 1.2406, AUROC: 0.7846, Precision: 0.2791, Recall: 0.9231, F1: 0.4286
# Epoch 74 - Train Loss: 17.5071, Val Loss: 1.4577, AUROC: 0.7524, Precision: 0.2281, Recall: 1.0000, F1: 0.3714
# Epoch 75 - Train Loss: 16.6988, Val Loss: 1.3103, AUROC: 0.7538, Precision: 0.2281, Recall: 1.0000, F1: 0.3714
# Epoch 76 - Train Loss: 12.9728, Val Loss: 1.1856, AUROC: 0.7706, Precision: 0.2281, Recall: 1.0000, F1: 0.3714
# Epoch 77 - Train Loss: 14.6556, Val Loss: 1.1374, AUROC: 0.7860, Precision: 0.2281, Recall: 1.0000, F1: 0.3714
# Epoch 78 - Train Loss: 16.9011, Val Loss: 1.1090, AUROC: 0.7958, Precision: 0.3250, Recall: 1.0000, F1: 0.4906
# Epoch 79 - Train Loss: 14.4571, Val Loss: 1.1279, AUROC: 0.7902, Precision: 0.2321, Recall: 1.0000, F1: 0.3768
# Epoch 80 - Train Loss: 14.6609, Val Loss: 1.1492, AUROC: 0.7846, Precision: 0.2203, Recall: 1.0000, F1: 0.3611
# Epoch 81 - Train Loss: 16.1511, Val Loss: 1.1200, AUROC: 0.7972, Precision: 0.2407, Recall: 1.0000, F1: 0.3881
# Epoch 82 - Train Loss: 12.4859, Val Loss: 1.1182, AUROC: 0.7930, Precision: 0.2708, Recall: 1.0000, F1: 0.4262
# Epoch 83 - Train Loss: 13.9824, Val Loss: 1.1456, AUROC: 0.7888, Precision: 0.2203, Recall: 1.0000, F1: 0.3611
# Epoch 84 - Train Loss: 13.5254, Val Loss: 1.1212, AUROC: 0.7972, Precision: 0.2955, Recall: 1.0000, F1: 0.4561
# Epoch 85 - Train Loss: 14.6362, Val Loss: 1.1258, AUROC: 0.7832, Precision: 0.3226, Recall: 0.7692, F1: 0.4545
# Epoch 86 - Train Loss: 13.8200, Val Loss: 1.1235, AUROC: 0.7804, Precision: 0.3571, Recall: 0.7692, F1: 0.4878
# Epoch 87 - Train Loss: 11.6032, Val Loss: 1.1220, AUROC: 0.7874, Precision: 0.3846, Recall: 0.7692, F1: 0.5128
# Epoch 88 - Train Loss: 13.1721, Val Loss: 1.1367, AUROC: 0.7916, Precision: 0.3810, Recall: 0.6154, F1: 0.4706
# Epoch 89 - Train Loss: 18.1515, Val Loss: 1.1196, AUROC: 0.7636, Precision: 0.2241, Recall: 1.0000, F1: 0.3662
# Epoch 90 - Train Loss: 15.4022, Val Loss: 1.1301, AUROC: 0.7510, Precision: 0.2097, Recall: 1.0000, F1: 0.3467
# Epoch 91 - Train Loss: 15.5528, Val Loss: 1.1260, AUROC: 0.7552, Precision: 0.2097, Recall: 1.0000, F1: 0.3467
# Epoch 92 - Train Loss: 13.5348, Val Loss: 1.1168, AUROC: 0.7720, Precision: 0.2549, Recall: 1.0000, F1: 0.4062
# Epoch 93 - Train Loss: 13.3104, Val Loss: 1.1810, AUROC: 0.7874, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 94 - Train Loss: 11.8180, Val Loss: 1.2956, AUROC: 0.7846, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 95 - Train Loss: 15.8666, Val Loss: 1.3407, AUROC: 0.7832, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 96 - Train Loss: 9.6751, Val Loss: 1.2626, AUROC: 0.7846, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 97 - Train Loss: 8.4486, Val Loss: 1.2027, AUROC: 0.7930, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 98 - Train Loss: 10.1452, Val Loss: 1.1969, AUROC: 0.7944, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 99 - Train Loss: 9.5477, Val Loss: 1.2060, AUROC: 0.7930, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 100 - Train Loss: 11.2436, Val Loss: 1.1874, AUROC: 0.7930, Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Epoch 101 - Train Loss: 12.0662, Val Loss: 1.1488, AUROC: 0.7944, Precision: 0.3684, Recall: 0.5385, F1: 0.4375
# Early stopping at epoch 101 with patience of 40

# %%
from itertools import product
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix
from statistics import mean, stdev
from sklearn.model_selection import RepeatedStratifiedKFold
import numpy as np
import torch, random, torch.nn as nn
from torch.utils.data import DataLoader

def run_kfold_gridsearch_with_external_val(
    train_dataset,
    external_val_dataset,
    param_grid,
    k=5,
    n_repeats=3,
    optimize_metric='f1'
):
    """
    Performs grid search over hyperparameters with repeated stratified k-fold cross-validation.
    Prints fold-level metrics and final best hyperparameters.
    """

    def train_one_fold(train_loader, val_loader, model, optimizer, criterion, seed):
        print("Training next fold...")
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        best_val_auroc, best_state, patience_counter = 0, None, 0

        for epoch in range(config.NUM_EPOCHS):
            model.train()
            for clin, mrna, mut, labels_batch in train_loader:
                clin, mrna, mut, labels_batch = (
                    clin.to(device),
                    mrna.to(device),
                    mut.to(device),
                    labels_batch.to(device),
                )
                optimizer.zero_grad()
                outputs = model(clin, mrna, mut)
                loss = criterion(outputs, labels_batch)
                loss.backward()
                optimizer.step()

            # Validation
            model.eval()
            all_labels, all_probs = [], []
            with torch.no_grad():
                for clin, mrna, mut, labels_batch in val_loader:
                    clin, mrna, mut, labels_batch = (
                        clin.to(device),
                        mrna.to(device),
                        mut.to(device),
                        labels_batch.to(device),
                    )
                    outputs = model(clin, mrna, mut)
                    probs = torch.sigmoid(outputs).cpu().numpy()
                    all_probs.append(probs)
                    all_labels.append(labels_batch.cpu().numpy())

            all_labels = np.concatenate(all_labels)
            all_probs = np.concatenate(all_probs)
            val_auroc = roc_auc_score(all_labels, all_probs)

            if val_auroc > best_val_auroc:
                best_val_auroc = val_auroc
                best_state = model.state_dict()
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= config.PATIENCE:
                    break

        return best_state

    labels = train_dataset.labels
    indices = np.arange(len(labels))
    ext_val_loader = DataLoader(external_val_dataset, batch_size=config.BATCH_SIZE)

    rskf = RepeatedStratifiedKFold(n_splits=k, n_repeats=n_repeats, random_state=SEED)
    param_combinations = list(product(*param_grid.values()))
    best_hyperparams, best_score = None, -1
    results_summary = {}

    for params in param_combinations:
        param_dict = dict(zip(param_grid.keys(), params))
        print(f"\n===== Testing hyperparams: {param_dict} =====")
        fold_metrics = {'auroc': [], 'precision': [], 'recall': [], 'f1': []}
        external_metrics = {'auroc': [], 'precision': [], 'recall': [], 'f1': []}

        for fold, (train_idx, val_idx) in enumerate(rskf.split(indices, labels)):
            print(f"\n--- Fold {fold + 1}/{k} ---")
            train_subset = torch.utils.data.Subset(train_dataset, train_idx)
            val_subset = torch.utils.data.Subset(train_dataset, val_idx)
            train_loader = DataLoader(train_subset, batch_size=config.BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_subset, batch_size=config.BATCH_SIZE)

            model = SimpleMultimodalNet(clin_dim, mrna_dim, mut_dim, **param_dict).to(device)
            optimizer = torch.optim.Adam(model.parameters())
            criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

            best_state = train_one_fold(train_loader, val_loader, model, optimizer, criterion, SEED + fold)
            model.load_state_dict(best_state)
            model.eval()

            # --- Validation predictions ---
            all_labels, all_probs = [], []
            with torch.no_grad():
                for clin, mrna, mut, labels_batch in val_loader:
                    clin, mrna, mut, labels_batch = (
                        clin.to(device),
                        mrna.to(device),
                        mut.to(device),
                        labels_batch.to(device),
                    )
                    outputs = model(clin, mrna, mut)
                    probs = torch.sigmoid(outputs).cpu().numpy()
                    all_probs.append(probs)
                    all_labels.append(labels_batch.cpu().numpy())

            all_labels = np.concatenate(all_labels)
            all_probs = np.concatenate(all_probs)

            # --- Find best threshold ---
            thresholds = np.linspace(0.001, 0.9, 200)
            best_t, best_m = 0.5, -1
            for t in thresholds:
                preds = (all_probs >= t).astype(float)
                if optimize_metric == 'f1':
                    m = f1_score(all_labels, preds, zero_division=0)
                else:
                    tn, fp, fn, tp = confusion_matrix(all_labels, preds).ravel()
                    sens, spec = tp / (tp + fn + 1e-9), tn / (tn + fp + 1e-9)
                    m = sens + spec - 1
                if m > best_m:
                    best_m, best_t = m, t

            preds = (all_probs >= best_t).astype(float)
            auroc = roc_auc_score(all_labels, all_probs)
            prec = precision_score(all_labels, preds, zero_division=0)
            rec = recall_score(all_labels, preds, zero_division=0)
            f1 = f1_score(all_labels, preds, zero_division=0)

            print(f"Fold {fold + 1} internal val metrics:")
            print(f"  AUROC={auroc:.4f}, Precision={prec:.4f}, Recall={rec:.4f}, F1={f1:.4f}")

            for k_, v_ in zip(['auroc', 'precision', 'recall', 'f1'], [auroc, prec, rec, f1]):
                fold_metrics[k_].append(v_)

            # --- External validation ---
            all_labels, all_probs = [], []
            with torch.no_grad():
                for clin, mrna, mut, labels_batch in ext_val_loader:
                    clin, mrna, mut, labels_batch = (
                        clin.to(device),
                        mrna.to(device),
                        mut.to(device),
                        labels_batch.to(device),
                    )
                    outputs = model(clin, mrna, mut)
                    probs = torch.sigmoid(outputs).cpu().numpy()
                    all_probs.append(probs)
                    all_labels.append(labels_batch.cpu().numpy())

            all_labels = np.concatenate(all_labels)
            all_probs = np.concatenate(all_probs)
            preds = (all_probs >= best_t).astype(float)
            auroc = roc_auc_score(all_labels, all_probs)
            prec = precision_score(all_labels, preds, zero_division=0)
            rec = recall_score(all_labels, preds, zero_division=0)
            f1 = f1_score(all_labels, preds, zero_division=0)

            print(f"  External test metrics:")
            print(f"  AUROC={auroc:.4f}, Precision={prec:.4f}, Recall={rec:.4f}, F1={f1:.4f}")

            for k_, v_ in zip(['auroc', 'precision', 'recall', 'f1'], [auroc, prec, rec, f1]):
                external_metrics[k_].append(v_)

        # --- Record results for this hyperparameter set ---
        results_summary[str(param_dict)] = {
            "internal": {k: (mean(v), stdev(v)) for k, v in fold_metrics.items()},
            "external": {k: (mean(v), stdev(v)) for k, v in external_metrics.items()}
        }

        print(f"\nAverage metrics for {param_dict}:")
        for phase in ["internal", "external"]:
            print(f"  {phase.upper()}:")
            for metric, (m, s) in results_summary[str(param_dict)][phase].items():
                print(f"    {metric}: {m:.4f} ± {s:.4f}")

        mean_f1 = results_summary[str(param_dict)]["internal"]["f1"][0]
        if mean_f1 > best_score:
            best_score = mean_f1
            best_hyperparams = param_dict

    print(f"\n=== Best hyperparameters: {best_hyperparams} (F1 = {best_score:.4f}) ===")

    return results_summary, best_hyperparams

    
param_grid = {
    'dropout': [0, 0.2, 0.3, 0.4],
    'hidden_dim': [32, 64, 128],
    'lr': [1e-3, 1e-4, 1e-5],
}

results_summary, best_hyperparams = run_kfold_gridsearch_with_external_val(
    train_dataset,
    val_dataset,
    param_grid,
    k=3,
    n_repeats=1,
    optimize_metric='f1'
)


def print_results_summary(results_summary):
    """
    Nicely prints the results summary from the k-fold grid search.
    """
    for param_str, metrics in results_summary.items():
        print("="*60)
        print(f"Hyperparameters: {param_str}")
        print("-"*60)
        for phase in ["internal", "external"]:
            print(f"{phase.upper()} METRICS:")
            for metric, (mean_val, std_val) in metrics[phase].items():
                print(f"  {metric:10}: {mean_val:.4f} ± {std_val:.4f}")
        print("="*60 + "\n")


print_results_summary(results_summary)
print(best_hyperparams)
# Out:
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 32, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8750, Precision=0.3462, Recall=0.9000, F1=0.5000
#   External test metrics:
#   AUROC=0.7357, Precision=0.2857, Recall=0.7692, F1=0.4167
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8207, Precision=0.5238, Recall=0.5789, F1=0.5500
#   External test metrics:
#   AUROC=0.7622, Precision=0.3333, Recall=0.3846, F1=0.3571
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7693, Precision=0.6000, Recall=0.4737, F1=0.5294
#   External test metrics:
#   AUROC=0.7741, Precision=0.3333, Recall=0.3846, F1=0.3571
#
# Average metrics for {'dropout': 0, 'hidden_dim': 32, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.8217 ± 0.0529
#     precision: 0.4900 ± 0.1303
#     recall: 0.6509 ± 0.2221
#     f1: 0.5265 ± 0.0251
#   EXTERNAL:
#     auroc: 0.7573 ± 0.0197
#     precision: 0.3175 ± 0.0275
#     recall: 0.5128 ± 0.2221
#     f1: 0.3770 ± 0.0344
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 32, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8343, Precision=0.5652, Recall=0.6500, F1=0.6047
#   External test metrics:
#   AUROC=0.6951, Precision=0.2632, Recall=0.3846, F1=0.3125
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8335, Precision=0.6250, Recall=0.5263, F1=0.5714
#   External test metrics:
#   AUROC=0.7455, Precision=0.3077, Recall=0.3077, F1=0.3077
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7876, Precision=0.4000, Recall=0.6316, F1=0.4898
#   External test metrics:
#   AUROC=0.7832, Precision=0.3571, Recall=0.7692, F1=0.4878
#
# Average metrics for {'dropout': 0, 'hidden_dim': 32, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.8185 ± 0.0267
#     precision: 0.5301 ± 0.1165
#     recall: 0.6026 ± 0.0667
#     f1: 0.5553 ± 0.0591
#   EXTERNAL:
#     auroc: 0.7413 ± 0.0442
#     precision: 0.3093 ± 0.0470
#     recall: 0.4872 ± 0.2473
#     f1: 0.3693 ± 0.1026
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 32, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8308, Precision=0.5185, Recall=0.7000, F1=0.5957
#   External test metrics:
#   AUROC=0.7371, Precision=0.3333, Recall=0.5385, F1=0.4118
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8152, Precision=0.5000, Recall=0.6316, F1=0.5581
#   External test metrics:
#   AUROC=0.7636, Precision=0.3333, Recall=0.3846, F1=0.3571
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7736, Precision=0.5333, Recall=0.4211, F1=0.4706
#   External test metrics:
#   AUROC=0.7846, Precision=0.2667, Recall=0.3077, F1=0.2857
#
# Average metrics for {'dropout': 0, 'hidden_dim': 32, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.8065 ± 0.0296
#     precision: 0.5173 ± 0.0167
#     recall: 0.5842 ± 0.1454
#     f1: 0.5415 ± 0.0642
#   EXTERNAL:
#     auroc: 0.7618 ± 0.0238
#     precision: 0.3111 ± 0.0385
#     recall: 0.4103 ± 0.1175
#     f1: 0.3515 ± 0.0632
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8355, Precision=0.5833, Recall=0.7000, F1=0.6364
#   External test metrics:
#   AUROC=0.7427, Precision=0.4118, Recall=0.5385, F1=0.4667
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8433, Precision=0.6000, Recall=0.6316, F1=0.6154
#   External test metrics:
#   AUROC=0.7357, Precision=0.3571, Recall=0.3846, F1=0.3704
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.6958, Precision=0.5000, Recall=0.4737, F1=0.4865
#   External test metrics:
#   AUROC=0.7678, Precision=0.3125, Recall=0.3846, F1=0.3448
#
# Average metrics for {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.7915 ± 0.0830
#     precision: 0.5611 ± 0.0536
#     recall: 0.6018 ± 0.1161
#     f1: 0.5794 ± 0.0812
#   EXTERNAL:
#     auroc: 0.7487 ± 0.0169
#     precision: 0.3605 ± 0.0497
#     recall: 0.4359 ± 0.0888
#     f1: 0.3940 ± 0.0643
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8116, Precision=0.5385, Recall=0.7000, F1=0.6087
#   External test metrics:
#   AUROC=0.7161, Precision=0.3333, Recall=0.4615, F1=0.3871
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7882, Precision=0.3939, Recall=0.6842, F1=0.5000
#   External test metrics:
#   AUROC=0.7643, Precision=0.3684, Recall=0.5385, F1=0.4375
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7791, Precision=0.5294, Recall=0.4737, F1=0.5000
#   External test metrics:
#   AUROC=0.7706, Precision=0.3571, Recall=0.3846, F1=0.3704
#
# Average metrics for {'dropout': 0, 'hidden_dim': 64, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.7930 ± 0.0168
#     precision: 0.4873 ± 0.0810
#     recall: 0.6193 ± 0.1264
#     f1: 0.5362 ± 0.0628
#   EXTERNAL:
#     auroc: 0.7503 ± 0.0298
#     precision: 0.3530 ± 0.0179
#     recall: 0.4615 ± 0.0769
#     f1: 0.3983 ± 0.0349
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8558, Precision=0.7857, Recall=0.5500, F1=0.6471
#   External test metrics:
#   AUROC=0.7245, Precision=0.4444, Recall=0.3077, F1=0.3636
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8329, Precision=0.5217, Recall=0.6316, F1=0.5714
#   External test metrics:
#   AUROC=0.7385, Precision=0.4118, Recall=0.5385, F1=0.4667
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7809, Precision=0.5625, Recall=0.4737, F1=0.5143
#   External test metrics:
#   AUROC=0.7762, Precision=0.3684, Recall=0.5385, F1=0.4375
#
# Average metrics for {'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.8232 ± 0.0384
#     precision: 0.6233 ± 0.1421
#     recall: 0.5518 ± 0.0790
#     f1: 0.5776 ± 0.0666
#   EXTERNAL:
#     auroc: 0.7464 ± 0.0268
#     precision: 0.4082 ± 0.0381
#     recall: 0.4615 ± 0.1332
#     f1: 0.4226 ± 0.0531
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 128, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8419, Precision=0.5385, Recall=0.7000, F1=0.6087
#   External test metrics:
#   AUROC=0.7147, Precision=0.2632, Recall=0.3846, F1=0.3125
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8348, Precision=0.5217, Recall=0.6316, F1=0.5714
#   External test metrics:
#   AUROC=0.7343, Precision=0.4615, Recall=0.4615, F1=0.4615
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7772, Precision=0.6000, Recall=0.4737, F1=0.5294
#   External test metrics:
#   AUROC=0.7734, Precision=0.3571, Recall=0.3846, F1=0.3704
#
# Average metrics for {'dropout': 0, 'hidden_dim': 128, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.8180 ± 0.0354
#     precision: 0.5534 ± 0.0412
#     recall: 0.6018 ± 0.1161
#     f1: 0.5698 ± 0.0397
#   EXTERNAL:
#     auroc: 0.7408 ± 0.0299
#     precision: 0.3606 ± 0.0992
#     recall: 0.4103 ± 0.0444
#     f1: 0.3815 ± 0.0751
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 128, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8369, Precision=0.4500, Recall=0.9000, F1=0.6000
#   External test metrics:
#   AUROC=0.7175, Precision=0.3462, Recall=0.6923, F1=0.4615
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8354, Precision=1.0000, Recall=0.2105, F1=0.3478
#   External test metrics:
#   AUROC=0.7238, Precision=0.4000, Recall=0.1538, F1=0.2222
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7656, Precision=0.5000, Recall=0.4211, F1=0.4571
#   External test metrics:
#   AUROC=0.7748, Precision=0.3125, Recall=0.3846, F1=0.3448
#
# Average metrics for {'dropout': 0, 'hidden_dim': 128, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.8126 ± 0.0407
#     precision: 0.6500 ± 0.3041
#     recall: 0.5105 ± 0.3533
#     f1: 0.4683 ± 0.1265
#   EXTERNAL:
#     auroc: 0.7387 ± 0.0314
#     precision: 0.3529 ± 0.0441
#     recall: 0.4103 ± 0.2701
#     f1: 0.3429 ± 0.1197
#
# ===== Testing hyperparams: {'dropout': 0, 'hidden_dim': 128, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8253, Precision=0.5000, Recall=0.7000, F1=0.5833
#   External test metrics:
#   AUROC=0.7329, Precision=0.3182, Recall=0.5385, F1=0.4000
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7993, Precision=0.4800, Recall=0.6316, F1=0.5455
#   External test metrics:
#   AUROC=0.7245, Precision=0.3529, Recall=0.4615, F1=0.4000
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7763, Precision=0.5000, Recall=0.4737, F1=0.4865
#   External test metrics:
#   AUROC=0.7608, Precision=0.2941, Recall=0.3846, F1=0.3333
#
# Average metrics for {'dropout': 0, 'hidden_dim': 128, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.8003 ± 0.0245
#     precision: 0.4933 ± 0.0115
#     recall: 0.6018 ± 0.1161
#     f1: 0.5384 ± 0.0488
#   EXTERNAL:
#     auroc: 0.7394 ± 0.0190
#     precision: 0.3217 ± 0.0296
#     recall: 0.4615 ± 0.0769
#     f1: 0.3778 ± 0.0385
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.6105, Precision=0.2299, Recall=1.0000, F1=0.3738
#   External test metrics:
#   AUROC=0.5727, Precision=0.2131, Recall=1.0000, F1=0.3514
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7980, Precision=0.4054, Recall=0.7895, F1=0.5357
#   External test metrics:
#   AUROC=0.7748, Precision=0.3684, Recall=0.5385, F1=0.4375
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7625, Precision=0.6000, Recall=0.4737, F1=0.5294
#   External test metrics:
#   AUROC=0.7902, Precision=0.3636, Recall=0.3077, F1=0.3333
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.7237 ± 0.0996
#     precision: 0.4118 ± 0.1851
#     recall: 0.7544 ± 0.2649
#     f1: 0.4797 ± 0.0917
#   EXTERNAL:
#     auroc: 0.7126 ± 0.1214
#     precision: 0.3151 ± 0.0883
#     recall: 0.6154 ± 0.3525
#     f1: 0.3741 ± 0.0557
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8070, Precision=0.4324, Recall=0.8000, F1=0.5614
#   External test metrics:
#   AUROC=0.7119, Precision=0.3462, Recall=0.6923, F1=0.4615
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8054, Precision=0.3778, Recall=0.8947, F1=0.5312
#   External test metrics:
#   AUROC=0.7832, Precision=0.3636, Recall=0.6154, F1=0.4571
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.3035, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.1972, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.6386 ± 0.2902
#     precision: 0.3304 ± 0.1323
#     recall: 0.8982 ± 0.1000
#     f1: 0.4664 ± 0.1393
#   EXTERNAL:
#     auroc: 0.5641 ± 0.3197
#     precision: 0.3003 ± 0.0949
#     recall: 0.7692 ± 0.2035
#     f1: 0.4132 ± 0.0799
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5500, Precision=0.1905, Recall=1.0000, F1=0.3200
#   External test metrics:
#   AUROC=0.4727, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7852, Precision=0.3810, Recall=0.8421, F1=0.5246
#   External test metrics:
#   AUROC=0.7762, Precision=0.3810, Recall=0.6154, F1=0.4706
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7466, Precision=0.5263, Recall=0.5263, F1=0.5263
#   External test metrics:
#   AUROC=0.7860, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 32, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.6939 ± 0.1261
#     precision: 0.3659 ± 0.1684
#     recall: 0.7895 ± 0.2412
#     f1: 0.4570 ± 0.1186
#   EXTERNAL:
#     auroc: 0.6783 ± 0.1781
#     precision: 0.3296 ± 0.1212
#     recall: 0.6667 ± 0.3109
#     f1: 0.3972 ± 0.0748
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8762, Precision=0.5152, Recall=0.8500, F1=0.6415
#   External test metrics:
#   AUROC=0.7944, Precision=0.3810, Recall=0.6154, F1=0.4706
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8072, Precision=0.3778, Recall=0.8947, F1=0.5312
#   External test metrics:
#   AUROC=0.7692, Precision=0.3600, Recall=0.6923, F1=0.4737
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7185, Precision=0.4211, Recall=0.4211, F1=0.4211
#   External test metrics:
#   AUROC=0.8084, Precision=0.4615, Recall=0.4615, F1=0.4615
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.8006 ± 0.0790
#     precision: 0.4380 ± 0.0702
#     recall: 0.7219 ± 0.2615
#     f1: 0.5313 ± 0.1102
#   EXTERNAL:
#     auroc: 0.7907 ± 0.0198
#     precision: 0.4008 ± 0.0536
#     recall: 0.5897 ± 0.1175
#     f1: 0.4686 ± 0.0063
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8488, Precision=0.4706, Recall=0.8000, F1=0.5926
#   External test metrics:
#   AUROC=0.7664, Precision=0.3529, Recall=0.4615, F1=0.4000
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7736, Precision=0.3750, Recall=0.7895, F1=0.5085
#   External test metrics:
#   AUROC=0.6951, Precision=0.4000, Recall=0.6154, F1=0.4848
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7534, Precision=0.5000, Recall=0.5263, F1=0.5128
#   External test metrics:
#   AUROC=0.7916, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.7919 ± 0.0503
#     precision: 0.4485 ± 0.0654
#     recall: 0.7053 ± 0.1551
#     f1: 0.5380 ± 0.0474
#   EXTERNAL:
#     auroc: 0.7510 ± 0.0501
#     precision: 0.3899 ± 0.0330
#     recall: 0.4872 ± 0.1175
#     f1: 0.4283 ± 0.0490
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8826, Precision=0.5185, Recall=0.7000, F1=0.5957
#   External test metrics:
#   AUROC=0.7874, Precision=0.4118, Recall=0.5385, F1=0.4667
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8072, Precision=0.3778, Recall=0.8947, F1=0.5312
#   External test metrics:
#   AUROC=0.7692, Precision=0.3600, Recall=0.6923, F1=0.4737
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7185, Precision=0.4211, Recall=0.4211, F1=0.4211
#   External test metrics:
#   AUROC=0.8084, Precision=0.4615, Recall=0.4615, F1=0.4615
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 64, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.8028 ± 0.0821
#     precision: 0.4391 ± 0.0721
#     recall: 0.6719 ± 0.2381
#     f1: 0.5160 ± 0.0883
#   EXTERNAL:
#     auroc: 0.7883 ± 0.0196
#     precision: 0.4111 ± 0.0508
#     recall: 0.5641 ± 0.1175
#     f1: 0.4673 ± 0.0061
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8756, Precision=0.5484, Recall=0.8500, F1=0.6667
#   External test metrics:
#   AUROC=0.7832, Precision=0.3684, Recall=0.5385, F1=0.4375
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7895, Precision=0.3947, Recall=0.7895, F1=0.5263
#   External test metrics:
#   AUROC=0.7636, Precision=0.4000, Recall=0.6154, F1=0.4848
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7656, Precision=0.5263, Recall=0.5263, F1=0.5263
#   External test metrics:
#   AUROC=0.7972, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.8102 ± 0.0578
#     precision: 0.4898 ± 0.0831
#     recall: 0.7219 ± 0.1721
#     f1: 0.5731 ± 0.0810
#   EXTERNAL:
#     auroc: 0.7814 ± 0.0169
#     precision: 0.3950 ± 0.0245
#     recall: 0.5128 ± 0.1175
#     f1: 0.4408 ± 0.0425
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8727, Precision=0.5517, Recall=0.8000, F1=0.6531
#   External test metrics:
#   AUROC=0.7804, Precision=0.3684, Recall=0.5385, F1=0.4375
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7938, Precision=0.4000, Recall=0.8421, F1=0.5424
#   External test metrics:
#   AUROC=0.7706, Precision=0.4000, Recall=0.6154, F1=0.4848
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7515, Precision=0.5263, Recall=0.5263, F1=0.5263
#   External test metrics:
#   AUROC=0.7930, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.8060 ± 0.0615
#     precision: 0.4927 ± 0.0813
#     recall: 0.7228 ± 0.1715
#     f1: 0.5739 ± 0.0690
#   EXTERNAL:
#     auroc: 0.7814 ± 0.0112
#     precision: 0.3950 ± 0.0245
#     recall: 0.5128 ± 0.1175
#     f1: 0.4408 ± 0.0425
#
# ===== Testing hyperparams: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8733, Precision=0.5769, Recall=0.7500, F1=0.6522
#   External test metrics:
#   AUROC=0.7846, Precision=0.4286, Recall=0.4615, F1=0.4444
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8109, Precision=0.3846, Recall=0.7895, F1=0.5172
#   External test metrics:
#   AUROC=0.7566, Precision=0.3810, Recall=0.6154, F1=0.4706
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7503, Precision=0.4762, Recall=0.5263, F1=0.5000
#   External test metrics:
#   AUROC=0.7762, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.2, 'hidden_dim': 128, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.8115 ± 0.0615
#     precision: 0.4792 ± 0.0962
#     recall: 0.6886 ± 0.1419
#     f1: 0.5565 ± 0.0833
#   EXTERNAL:
#     auroc: 0.7725 ± 0.0144
#     precision: 0.4087 ± 0.0248
#     recall: 0.4872 ± 0.1175
#     f1: 0.4383 ± 0.0357
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5570, Precision=0.2254, Recall=0.8000, F1=0.3516
#   External test metrics:
#   AUROC=0.6294, Precision=0.2340, Recall=0.8462, F1=0.3667
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7834, Precision=0.3333, Recall=0.4211, F1=0.3721
#   External test metrics:
#   AUROC=0.7790, Precision=0.3846, Recall=0.3846, F1=0.3846
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7546, Precision=0.5263, Recall=0.5263, F1=0.5263
#   External test metrics:
#   AUROC=0.7818, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.6983 ± 0.1232
#     precision: 0.3617 ± 0.1525
#     recall: 0.5825 ± 0.1956
#     f1: 0.4167 ± 0.0955
#   EXTERNAL:
#     auroc: 0.7301 ± 0.0872
#     precision: 0.3451 ± 0.0975
#     recall: 0.5385 ± 0.2665
#     f1: 0.3838 ± 0.0167
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5157, Precision=0.2118, Recall=0.9000, F1=0.3429
#   External test metrics:
#   AUROC=0.4350, Precision=0.1930, Recall=0.8462, F1=0.3143
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.5058, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7466, Precision=0.5263, Recall=0.5263, F1=0.5263
#   External test metrics:
#   AUROC=0.7958, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.5894 ± 0.1363
#     precision: 0.3063 ± 0.1911
#     recall: 0.8088 ± 0.2497
#     f1: 0.3919 ± 0.1178
#   EXTERNAL:
#     auroc: 0.5769 ± 0.1923
#     precision: 0.2669 ± 0.1297
#     recall: 0.7436 ± 0.3203
#     f1: 0.3451 ± 0.0477
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.4750, Precision=0.1887, Recall=1.0000, F1=0.3175
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.2607, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.2245, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.6463, Precision=0.3103, Recall=0.4737, F1=0.3750
#   External test metrics:
#   AUROC=0.7594, Precision=0.4000, Recall=0.6154, F1=0.4848
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 32, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.4607 ± 0.1932
#     precision: 0.2267 ± 0.0726
#     recall: 0.8246 ± 0.3039
#     f1: 0.3330 ± 0.0368
#   EXTERNAL:
#     auroc: 0.4946 ± 0.2675
#     precision: 0.2608 ± 0.1206
#     recall: 0.8718 ± 0.2221
#     f1: 0.3756 ± 0.0946
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.4203, Precision=0.2299, Recall=1.0000, F1=0.3738
#   External test metrics:
#   AUROC=0.3497, Precision=0.2031, Recall=1.0000, F1=0.3377
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.8155, Precision=0.3269, Recall=0.8947, F1=0.4789
#   External test metrics:
#   AUROC=0.7692, Precision=0.3600, Recall=0.6923, F1=0.4737
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.6420, Precision=0.2368, Recall=0.9474, F1=0.3789
#   External test metrics:
#   AUROC=0.7580, Precision=0.2364, Recall=1.0000, F1=0.3824
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.6259 ± 0.1981
#     precision: 0.2646 ± 0.0541
#     recall: 0.9474 ± 0.0526
#     f1: 0.4106 ± 0.0592
#   EXTERNAL:
#     auroc: 0.6256 ± 0.2391
#     precision: 0.2665 ± 0.0827
#     recall: 0.8974 ± 0.1776
#     f1: 0.3979 ± 0.0693
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5407, Precision=0.2000, Recall=1.0000, F1=0.3333
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.5233, Precision=0.1845, Recall=1.0000, F1=0.3115
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7528, Precision=0.4762, Recall=0.5263, F1=0.5000
#   External test metrics:
#   AUROC=0.7832, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.6056 ± 0.1278
#     precision: 0.2869 ± 0.1641
#     recall: 0.8421 ± 0.2735
#     f1: 0.3816 ± 0.1031
#   EXTERNAL:
#     auroc: 0.5944 ± 0.1635
#     precision: 0.2663 ± 0.1302
#     recall: 0.7949 ± 0.3553
#     f1: 0.3473 ± 0.0456
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8436, Precision=0.5152, Recall=0.8500, F1=0.6415
#   External test metrics:
#   AUROC=0.8000, Precision=0.3889, Recall=0.5385, F1=0.4516
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7118, Precision=0.2881, Recall=0.8947, F1=0.4359
#   External test metrics:
#   AUROC=0.7874, Precision=0.2895, Recall=0.8462, F1=0.4314
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7430, Precision=0.4500, Recall=0.4737, F1=0.4615
#   External test metrics:
#   AUROC=0.7860, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 64, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.7661 ± 0.0689
#     precision: 0.4178 ± 0.1169
#     recall: 0.7395 ± 0.2313
#     f1: 0.5130 ± 0.1120
#   EXTERNAL:
#     auroc: 0.7911 ± 0.0077
#     precision: 0.3650 ± 0.0669
#     recall: 0.5897 ± 0.2350
#     f1: 0.4277 ± 0.0260
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8773, Precision=0.5714, Recall=0.8000, F1=0.6667
#   External test metrics:
#   AUROC=0.8028, Precision=0.3333, Recall=0.3846, F1=0.3571
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7087, Precision=0.2909, Recall=0.8421, F1=0.4324
#   External test metrics:
#   AUROC=0.7734, Precision=0.3667, Recall=0.8462, F1=0.5116
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7411, Precision=0.4737, Recall=0.4737, F1=0.4737
#   External test metrics:
#   AUROC=0.7958, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.7757 ± 0.0895
#     precision: 0.4453 ± 0.1424
#     recall: 0.7053 ± 0.2017
#     f1: 0.5243 ± 0.1250
#   EXTERNAL:
#     auroc: 0.7907 ± 0.0153
#     precision: 0.3722 ± 0.0419
#     recall: 0.5385 ± 0.2665
#     f1: 0.4229 ± 0.0798
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5116, Precision=0.1923, Recall=1.0000, F1=0.3226
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.4315, Precision=0.2135, Recall=1.0000, F1=0.3519
#   External test metrics:
#   AUROC=0.5580, Precision=0.2241, Recall=1.0000, F1=0.3662
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7430, Precision=0.4545, Recall=0.5263, F1=0.4878
#   External test metrics:
#   AUROC=0.7902, Precision=0.3846, Recall=0.3846, F1=0.3846
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.5620 ± 0.1618
#     precision: 0.2868 ± 0.1457
#     recall: 0.8421 ± 0.2735
#     f1: 0.3874 ± 0.0882
#   EXTERNAL:
#     auroc: 0.6161 ± 0.1536
#     precision: 0.2666 ± 0.1035
#     recall: 0.7949 ± 0.3553
#     f1: 0.3573 ± 0.0327
#
# ===== Testing hyperparams: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8477, Precision=0.6087, Recall=0.7000, F1=0.6512
#   External test metrics:
#   AUROC=0.8000, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.4315, Precision=0.2135, Recall=1.0000, F1=0.3519
#   External test metrics:
#   AUROC=0.5580, Precision=0.2241, Recall=1.0000, F1=0.3662
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7430, Precision=0.4545, Recall=0.5263, F1=0.4878
#   External test metrics:
#   AUROC=0.7902, Precision=0.3846, Recall=0.3846, F1=0.3846
#
# Average metrics for {'dropout': 0.3, 'hidden_dim': 128, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.6740 ± 0.2165
#     precision: 0.4256 ± 0.1992
#     recall: 0.7421 ± 0.2396
#     f1: 0.4969 ± 0.1499
#   EXTERNAL:
#     auroc: 0.7161 ± 0.1370
#     precision: 0.3418 ± 0.1032
#     recall: 0.5897 ± 0.3553
#     f1: 0.3836 ± 0.0169
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.4750, Precision=0.1887, Recall=1.0000, F1=0.3175
#   External test metrics:
#   AUROC=0.5091, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.6089, Precision=0.2500, Recall=0.8947, F1=0.3908
#   External test metrics:
#   AUROC=0.7357, Precision=0.2619, Recall=0.8462, F1=0.4000
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7154, Precision=0.4091, Recall=0.4737, F1=0.4390
#   External test metrics:
#   AUROC=0.8084, Precision=0.4000, Recall=0.4615, F1=0.4286
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.5998 ± 0.1205
#     precision: 0.2826 ± 0.1138
#     recall: 0.7895 ± 0.2785
#     f1: 0.3824 ± 0.0612
#   EXTERNAL:
#     auroc: 0.6844 ± 0.1561
#     precision: 0.2844 ± 0.1062
#     recall: 0.7692 ± 0.2774
#     f1: 0.3832 ± 0.0557
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5651, Precision=0.2466, Recall=0.9000, F1=0.3871
#   External test metrics:
#   AUROC=0.4434, Precision=0.2069, Recall=0.9231, F1=0.3380
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.5058, Precision=0.1827, Recall=1.0000, F1=0.3089
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7540, Precision=0.4167, Recall=0.5263, F1=0.4651
#   External test metrics:
#   AUROC=0.7944, Precision=0.4000, Recall=0.4615, F1=0.4286
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.6083 ± 0.1296
#     precision: 0.2820 ± 0.1209
#     recall: 0.8088 ± 0.2497
#     f1: 0.3871 ± 0.0781
#   EXTERNAL:
#     auroc: 0.5793 ± 0.1885
#     precision: 0.2660 ± 0.1163
#     recall: 0.7949 ± 0.2912
#     f1: 0.3625 ± 0.0578
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5637, Precision=0.2020, Recall=1.0000, F1=0.3361
#   External test metrics:
#   AUROC=0.5091, Precision=0.1940, Recall=1.0000, F1=0.3250
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.7625, Precision=0.3617, Recall=0.8947, F1=0.5152
#   External test metrics:
#   AUROC=0.7888, Precision=0.3462, Recall=0.6923, F1=0.4615
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.5523, Precision=0.1979, Recall=1.0000, F1=0.3304
#   External test metrics:
#   AUROC=0.5182, Precision=0.1970, Recall=1.0000, F1=0.3291
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 32, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.6262 ± 0.1182
#     precision: 0.2539 ± 0.0934
#     recall: 0.9649 ± 0.0608
#     f1: 0.3939 ± 0.1050
#   EXTERNAL:
#     auroc: 0.6054 ± 0.1589
#     precision: 0.2457 ± 0.0870
#     recall: 0.8974 ± 0.1776
#     f1: 0.3719 ± 0.0777
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.2110, Precision=0.1887, Recall=1.0000, F1=0.3175
#   External test metrics:
#   AUROC=0.3259, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.1928, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.3245, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7166, Precision=0.2571, Recall=0.9474, F1=0.4045
#   External test metrics:
#   AUROC=0.7944, Precision=0.2549, Recall=1.0000, F1=0.4062
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.3735 ± 0.2973
#     precision: 0.2089 ± 0.0419
#     recall: 0.9825 ± 0.0304
#     f1: 0.3428 ± 0.0537
#   EXTERNAL:
#     auroc: 0.4816 ± 0.2709
#     precision: 0.2124 ± 0.0368
#     recall: 1.0000 ± 0.0000
#     f1: 0.3494 ± 0.0492
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5000, Precision=0.1887, Recall=1.0000, F1=0.3175
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.5523, Precision=0.1979, Recall=1.0000, F1=0.3304
#   External test metrics:
#   AUROC=0.5273, Precision=0.1940, Recall=1.0000, F1=0.3250
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7301, Precision=0.4706, Recall=0.4211, F1=0.4444
#   External test metrics:
#   AUROC=0.7154, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.5941 ± 0.1206
#     precision: 0.2857 ± 0.1602
#     recall: 0.8070 ± 0.3343
#     f1: 0.3641 ± 0.0699
#   EXTERNAL:
#     auroc: 0.5809 ± 0.1173
#     precision: 0.2673 ± 0.1294
#     recall: 0.7949 ± 0.3553
#     f1: 0.3487 ± 0.0445
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5000, Precision=0.1887, Recall=1.0000, F1=0.3175
#   External test metrics:
#   AUROC=0.5000, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.4535, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.4909, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7601, Precision=0.5000, Recall=0.5263, F1=0.5128
#   External test metrics:
#   AUROC=0.7874, Precision=0.4000, Recall=0.4615, F1=0.4286
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 64, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.5712 ± 0.1652
#     precision: 0.2899 ± 0.1820
#     recall: 0.8421 ± 0.2735
#     f1: 0.3789 ± 0.1161
#   EXTERNAL:
#     auroc: 0.5928 ± 0.1686
#     precision: 0.2608 ± 0.1206
#     recall: 0.8205 ± 0.3109
#     f1: 0.3568 ± 0.0621
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.8483, Precision=0.5909, Recall=0.6500, F1=0.6190
#   External test metrics:
#   AUROC=0.7594, Precision=0.4615, Recall=0.4615, F1=0.4615
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.6646, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.5455, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7056, Precision=0.1810, Recall=1.0000, F1=0.3065
#   External test metrics:
#   AUROC=0.6168, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.001}:
#   INTERNAL:
#     auroc: 0.7395 ± 0.0964
#     precision: 0.3176 ± 0.2367
#     recall: 0.8833 ± 0.2021
#     f1: 0.4107 ± 0.1805
#   EXTERNAL:
#     auroc: 0.6406 ± 0.1090
#     precision: 0.2813 ± 0.1561
#     recall: 0.8205 ± 0.3109
#     f1: 0.3678 ± 0.0811
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.0001} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.5858, Precision=0.2105, Recall=1.0000, F1=0.3478
#   External test metrics:
#   AUROC=0.5364, Precision=0.2031, Recall=1.0000, F1=0.3377
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.6395, Precision=0.2021, Recall=1.0000, F1=0.3363
#   External test metrics:
#   AUROC=0.6364, Precision=0.2063, Recall=1.0000, F1=0.3421
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7356, Precision=0.4737, Recall=0.4737, F1=0.4737
#   External test metrics:
#   AUROC=0.7755, Precision=0.4167, Recall=0.3846, F1=0.4000
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.0001}:
#   INTERNAL:
#     auroc: 0.6536 ± 0.0759
#     precision: 0.2954 ± 0.1544
#     recall: 0.8246 ± 0.3039
#     f1: 0.3859 ± 0.0762
#   EXTERNAL:
#     auroc: 0.6494 ± 0.1201
#     precision: 0.2754 ± 0.1224
#     recall: 0.7949 ± 0.3553
#     f1: 0.3599 ± 0.0348
#
# ===== Testing hyperparams: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 1e-05} =====
#
# --- Fold 1/3 ---
# Training next fold...
# Fold 1 internal val metrics:
#   AUROC=0.6852, Precision=0.2564, Recall=1.0000, F1=0.4082
#   External test metrics:
#   AUROC=0.6091, Precision=0.2321, Recall=1.0000, F1=0.3768
#
# --- Fold 2/3 ---
# Training next fold...
# Fold 2 internal val metrics:
#   AUROC=0.5291, Precision=0.1900, Recall=1.0000, F1=0.3193
#   External test metrics:
#   AUROC=0.4909, Precision=0.1912, Recall=1.0000, F1=0.3210
#
# --- Fold 3/3 ---
# Training next fold...
# Fold 3 internal val metrics:
#   AUROC=0.7020, Precision=0.3913, Recall=0.4737, F1=0.4286
#   External test metrics:
#   AUROC=0.7594, Precision=0.4615, Recall=0.4615, F1=0.4615
#
# Average metrics for {'dropout': 0.4, 'hidden_dim': 128, 'lr': 1e-05}:
#   INTERNAL:
#     auroc: 0.6387 ± 0.0953
#     precision: 0.2792 ± 0.1026
#     recall: 0.8246 ± 0.3039
#     f1: 0.3854 ± 0.0581
#   EXTERNAL:
#     auroc: 0.6198 ± 0.1346
#     precision: 0.2950 ± 0.1457
#     recall: 0.8205 ± 0.3109
#     f1: 0.3864 ± 0.0708
#
# === Best hyperparameters: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001} (F1 = 0.5794) ===
# {"{'dropout': 0, 'hidden_dim': 32, 'lr': 0.001}": {'internal': {'auroc': (0.8216544267645859, 0.05286773763703342), 'precision': (0.48998778998778997, 0.13025897172422504), 'recall': (0.6508771929824562, 0.2220736653336419), 'f1': (0.5264705882352941, 0.0251294227803457)}, 'external': {'auroc': (0.7573426573426574, 0.01969248648997024), 'precision': (0.31746031746031744, 0.02749286996141075), 'recall': (0.5128205128205129, 0.22205779584216376), 'f1': (0.376984126984127, 0.03436608745176344)}}, "{'dropout': 0, 'hidden_dim': 32, 'lr': 0.0001}": {'internal': {'auroc': (0.8184924520603836, 0.02672373754593317), 'precision': (0.5300724637681159, 0.11654451702523477), 'recall': (0.6026315789473684, 0.066730117542663), 'f1': (0.5552918841955387, 0.059103521883466896)}, 'external': {'auroc': (0.7412587412587412, 0.04420554022175973), 'precision': (0.30933101985733563, 0.04701390563210925), 'recall': (0.4871794871794872, 0.24727309643571682), 'f1': (0.3693323952470294, 0.10262833605900354)}}, "{'dropout': 0, 'hidden_dim': 32, 'lr': 1e-05}": {'internal': {'auroc': (0.8065177478580171, 0.029592146636255937), 'precision': (0.5172839506172839, 0.01670092501045516), 'recall': (0.5842105263157894, 0.1453813401782435), 'f1': (0.5414908170096341, 0.06421774537657336)}, 'external': {'auroc': (0.7617715617715618, 0.02383100777460525), 'precision': (0.3111111111111111, 0.03849001794597504), 'recall': (0.41025641025641024, 0.11750194089630357), 'f1': (0.35154061624649857, 0.06321167561006587)}}, "{'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}": {'internal': {'auroc': (0.7915442676458588, 0.0829769016653429), 'precision': (0.5611111111111111, 0.053575837561071975), 'recall': (0.6017543859649123, 0.11606824496156554), 'f1': (0.5794115794115794, 0.0811562351373104)}, 'external': {'auroc': (0.7487179487179487, 0.01691864551200377), 'precision': (0.36046918767507, 0.049715880909269386), 'recall': (0.4358974358974359, 0.08882311833686547), 'f1': (0.39395487441464455, 0.0642523307365684)}}, "{'dropout': 0, 'hidden_dim': 64, 'lr': 0.0001}": {'internal': {'auroc': (0.7929824561403509, 0.01678711978225311), 'precision': (0.4872708990356049, 0.08095401153679899), 'recall': (0.619298245614035, 0.12635233389495326), 'f1': (0.5362318840579711, 0.06275546404235065)}, 'external': {'auroc': (0.7503496503496504, 0.029841382228464188), 'precision': (0.3529657477025898, 0.017912933702916932), 'recall': (0.46153846153846156, 0.0769230769230769), 'f1': (0.3983223815213062, 0.03494434844807628)}}, "{'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05}": {'internal': {'auroc': (0.8232150142798859, 0.03838655238422999), 'precision': (0.6233178053830227, 0.1421084963677924), 'recall': (0.5517543859649123, 0.07896198695065132), 'f1': (0.5775910364145658, 0.06660072533829806)}, 'external': {'auroc': (0.7463869463869464, 0.026769001808774916), 'precision': (0.4082100676527921, 0.038136145785729415), 'recall': (0.4615384615384615, 0.13323467750529822), 'f1': (0.4226010101010101, 0.053106456863894334)}}, "{'dropout': 0, 'hidden_dim': 128, 'lr': 0.001}": {'internal': {'auroc': (0.8179518563851489, 0.03544108684661666), 'precision': (0.5534002229654403, 0.04121364030641229), 'recall': (0.6017543859649123, 0.11606824496156554), 'f1': (0.5698453294361223, 0.03966564879610354)}, 'external': {'auroc': (0.7407925407925409, 0.029909584955422654), 'precision': (0.36061307113938695, 0.09923580054606923), 'recall': (0.4102564102564103, 0.04441155916843275), 'f1': (0.3814696106362773, 0.07513661294800371)}}, "{'dropout': 0, 'hidden_dim': 128, 'lr': 0.0001}": {'internal': {'auroc': (0.8126325989392086, 0.04073366594132123), 'precision': (0.65, 0.30413812651491096), 'recall': (0.5105263157894737, 0.3533378629999379), 'f1': (0.4683229813664596, 0.12645816299534135)}, 'external': {'auroc': (0.7386946386946387, 0.031447804621910234), 'precision': (0.3528846153846154, 0.04413660545203271), 'recall': (0.41025641025641024, 0.2701449680218651), 'f1': (0.34286275665586013, 0.1196702177506599)}}, "{'dropout': ...
# {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}

# %%
def print_results_summary(results_summary):
    """
    Nicely prints the results summary from the k-fold grid search.
    """
    for param_str, metrics in results_summary.items():
        print("="*60)
        print(f"Hyperparameters: {param_str}")
        print("-"*60)
        for phase in ["internal", "external"]:
            print(f"{phase.upper()} METRICS:")
            for metric, (mean_val, std_val) in metrics[phase].items():
                print(f"  {metric:10}: {mean_val:.4f} ± {std_val:.4f}")
        print("="*60 + "\n")

print_results_summary(results_summary)
print(best_hyperparams)
# Best hyperparameters: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}
# Out:
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 32, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8217 ± 0.0529
#   precision : 0.4900 ± 0.1303
#   recall    : 0.6509 ± 0.2221
#   f1        : 0.5265 ± 0.0251
# EXTERNAL METRICS:
#   auroc     : 0.7573 ± 0.0197
#   precision : 0.3175 ± 0.0275
#   recall    : 0.5128 ± 0.2221
#   f1        : 0.3770 ± 0.0344
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 32, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8185 ± 0.0267
#   precision : 0.5301 ± 0.1165
#   recall    : 0.6026 ± 0.0667
#   f1        : 0.5553 ± 0.0591
# EXTERNAL METRICS:
#   auroc     : 0.7413 ± 0.0442
#   precision : 0.3093 ± 0.0470
#   recall    : 0.4872 ± 0.2473
#   f1        : 0.3693 ± 0.1026
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 32, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8065 ± 0.0296
#   precision : 0.5173 ± 0.0167
#   recall    : 0.5842 ± 0.1454
#   f1        : 0.5415 ± 0.0642
# EXTERNAL METRICS:
#   auroc     : 0.7618 ± 0.0238
#   precision : 0.3111 ± 0.0385
#   recall    : 0.4103 ± 0.1175
#   f1        : 0.3515 ± 0.0632
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7915 ± 0.0830
#   precision : 0.5611 ± 0.0536
#   recall    : 0.6018 ± 0.1161
#   f1        : 0.5794 ± 0.0812
# EXTERNAL METRICS:
#   auroc     : 0.7487 ± 0.0169
#   precision : 0.3605 ± 0.0497
#   recall    : 0.4359 ± 0.0888
#   f1        : 0.3940 ± 0.0643
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 64, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7930 ± 0.0168
#   precision : 0.4873 ± 0.0810
#   recall    : 0.6193 ± 0.1264
#   f1        : 0.5362 ± 0.0628
# EXTERNAL METRICS:
#   auroc     : 0.7503 ± 0.0298
#   precision : 0.3530 ± 0.0179
#   recall    : 0.4615 ± 0.0769
#   f1        : 0.3983 ± 0.0349
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8232 ± 0.0384
#   precision : 0.6233 ± 0.1421
#   recall    : 0.5518 ± 0.0790
#   f1        : 0.5776 ± 0.0666
# EXTERNAL METRICS:
#   auroc     : 0.7464 ± 0.0268
#   precision : 0.4082 ± 0.0381
#   recall    : 0.4615 ± 0.1332
#   f1        : 0.4226 ± 0.0531
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 128, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8180 ± 0.0354
#   precision : 0.5534 ± 0.0412
#   recall    : 0.6018 ± 0.1161
#   f1        : 0.5698 ± 0.0397
# EXTERNAL METRICS:
#   auroc     : 0.7408 ± 0.0299
#   precision : 0.3606 ± 0.0992
#   recall    : 0.4103 ± 0.0444
#   f1        : 0.3815 ± 0.0751
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 128, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8126 ± 0.0407
#   precision : 0.6500 ± 0.3041
#   recall    : 0.5105 ± 0.3533
#   f1        : 0.4683 ± 0.1265
# EXTERNAL METRICS:
#   auroc     : 0.7387 ± 0.0314
#   precision : 0.3529 ± 0.0441
#   recall    : 0.4103 ± 0.2701
#   f1        : 0.3429 ± 0.1197
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0, 'hidden_dim': 128, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8003 ± 0.0245
#   precision : 0.4933 ± 0.0115
#   recall    : 0.6018 ± 0.1161
#   f1        : 0.5384 ± 0.0488
# EXTERNAL METRICS:
#   auroc     : 0.7394 ± 0.0190
#   precision : 0.3217 ± 0.0296
#   recall    : 0.4615 ± 0.0769
#   f1        : 0.3778 ± 0.0385
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7237 ± 0.0996
#   precision : 0.4118 ± 0.1851
#   recall    : 0.7544 ± 0.2649
#   f1        : 0.4797 ± 0.0917
# EXTERNAL METRICS:
#   auroc     : 0.7126 ± 0.1214
#   precision : 0.3151 ± 0.0883
#   recall    : 0.6154 ± 0.3525
#   f1        : 0.3741 ± 0.0557
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6386 ± 0.2902
#   precision : 0.3304 ± 0.1323
#   recall    : 0.8982 ± 0.1000
#   f1        : 0.4664 ± 0.1393
# EXTERNAL METRICS:
#   auroc     : 0.5641 ± 0.3197
#   precision : 0.3003 ± 0.0949
#   recall    : 0.7692 ± 0.2035
#   f1        : 0.4132 ± 0.0799
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 32, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6939 ± 0.1261
#   precision : 0.3659 ± 0.1684
#   recall    : 0.7895 ± 0.2412
#   f1        : 0.4570 ± 0.1186
# EXTERNAL METRICS:
#   auroc     : 0.6783 ± 0.1781
#   precision : 0.3296 ± 0.1212
#   recall    : 0.6667 ± 0.3109
#   f1        : 0.3972 ± 0.0748
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8006 ± 0.0790
#   precision : 0.4380 ± 0.0702
#   recall    : 0.7219 ± 0.2615
#   f1        : 0.5313 ± 0.1102
# EXTERNAL METRICS:
#   auroc     : 0.7907 ± 0.0198
#   precision : 0.4008 ± 0.0536
#   recall    : 0.5897 ± 0.1175
#   f1        : 0.4686 ± 0.0063
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7919 ± 0.0503
#   precision : 0.4485 ± 0.0654
#   recall    : 0.7053 ± 0.1551
#   f1        : 0.5380 ± 0.0474
# EXTERNAL METRICS:
#   auroc     : 0.7510 ± 0.0501
#   precision : 0.3899 ± 0.0330
#   recall    : 0.4872 ± 0.1175
#   f1        : 0.4283 ± 0.0490
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 64, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8028 ± 0.0821
#   precision : 0.4391 ± 0.0721
#   recall    : 0.6719 ± 0.2381
#   f1        : 0.5160 ± 0.0883
# EXTERNAL METRICS:
#   auroc     : 0.7883 ± 0.0196
#   precision : 0.4111 ± 0.0508
#   recall    : 0.5641 ± 0.1175
#   f1        : 0.4673 ± 0.0061
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8102 ± 0.0578
#   precision : 0.4898 ± 0.0831
#   recall    : 0.7219 ± 0.1721
#   f1        : 0.5731 ± 0.0810
# EXTERNAL METRICS:
#   auroc     : 0.7814 ± 0.0169
#   precision : 0.3950 ± 0.0245
#   recall    : 0.5128 ± 0.1175
#   f1        : 0.4408 ± 0.0425
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8060 ± 0.0615
#   precision : 0.4927 ± 0.0813
#   recall    : 0.7228 ± 0.1715
#   f1        : 0.5739 ± 0.0690
# EXTERNAL METRICS:
#   auroc     : 0.7814 ± 0.0112
#   precision : 0.3950 ± 0.0245
#   recall    : 0.5128 ± 0.1175
#   f1        : 0.4408 ± 0.0425
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.2, 'hidden_dim': 128, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.8115 ± 0.0615
#   precision : 0.4792 ± 0.0962
#   recall    : 0.6886 ± 0.1419
#   f1        : 0.5565 ± 0.0833
# EXTERNAL METRICS:
#   auroc     : 0.7725 ± 0.0144
#   precision : 0.4087 ± 0.0248
#   recall    : 0.4872 ± 0.1175
#   f1        : 0.4383 ± 0.0357
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6983 ± 0.1232
#   precision : 0.3617 ± 0.1525
#   recall    : 0.5825 ± 0.1956
#   f1        : 0.4167 ± 0.0955
# EXTERNAL METRICS:
#   auroc     : 0.7301 ± 0.0872
#   precision : 0.3451 ± 0.0975
#   recall    : 0.5385 ± 0.2665
#   f1        : 0.3838 ± 0.0167
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.5894 ± 0.1363
#   precision : 0.3063 ± 0.1911
#   recall    : 0.8088 ± 0.2497
#   f1        : 0.3919 ± 0.1178
# EXTERNAL METRICS:
#   auroc     : 0.5769 ± 0.1923
#   precision : 0.2669 ± 0.1297
#   recall    : 0.7436 ± 0.3203
#   f1        : 0.3451 ± 0.0477
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 32, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.4607 ± 0.1932
#   precision : 0.2267 ± 0.0726
#   recall    : 0.8246 ± 0.3039
#   f1        : 0.3330 ± 0.0368
# EXTERNAL METRICS:
#   auroc     : 0.4946 ± 0.2675
#   precision : 0.2608 ± 0.1206
#   recall    : 0.8718 ± 0.2221
#   f1        : 0.3756 ± 0.0946
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6259 ± 0.1981
#   precision : 0.2646 ± 0.0541
#   recall    : 0.9474 ± 0.0526
#   f1        : 0.4106 ± 0.0592
# EXTERNAL METRICS:
#   auroc     : 0.6256 ± 0.2391
#   precision : 0.2665 ± 0.0827
#   recall    : 0.8974 ± 0.1776
#   f1        : 0.3979 ± 0.0693
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6056 ± 0.1278
#   precision : 0.2869 ± 0.1641
#   recall    : 0.8421 ± 0.2735
#   f1        : 0.3816 ± 0.1031
# EXTERNAL METRICS:
#   auroc     : 0.5944 ± 0.1635
#   precision : 0.2663 ± 0.1302
#   recall    : 0.7949 ± 0.3553
#   f1        : 0.3473 ± 0.0456
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 64, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7661 ± 0.0689
#   precision : 0.4178 ± 0.1169
#   recall    : 0.7395 ± 0.2313
#   f1        : 0.5130 ± 0.1120
# EXTERNAL METRICS:
#   auroc     : 0.7911 ± 0.0077
#   precision : 0.3650 ± 0.0669
#   recall    : 0.5897 ± 0.2350
#   f1        : 0.4277 ± 0.0260
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7757 ± 0.0895
#   precision : 0.4453 ± 0.1424
#   recall    : 0.7053 ± 0.2017
#   f1        : 0.5243 ± 0.1250
# EXTERNAL METRICS:
#   auroc     : 0.7907 ± 0.0153
#   precision : 0.3722 ± 0.0419
#   recall    : 0.5385 ± 0.2665
#   f1        : 0.4229 ± 0.0798
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.5620 ± 0.1618
#   precision : 0.2868 ± 0.1457
#   recall    : 0.8421 ± 0.2735
#   f1        : 0.3874 ± 0.0882
# EXTERNAL METRICS:
#   auroc     : 0.6161 ± 0.1536
#   precision : 0.2666 ± 0.1035
#   recall    : 0.7949 ± 0.3553
#   f1        : 0.3573 ± 0.0327
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.3, 'hidden_dim': 128, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6740 ± 0.2165
#   precision : 0.4256 ± 0.1992
#   recall    : 0.7421 ± 0.2396
#   f1        : 0.4969 ± 0.1499
# EXTERNAL METRICS:
#   auroc     : 0.7161 ± 0.1370
#   precision : 0.3418 ± 0.1032
#   recall    : 0.5897 ± 0.3553
#   f1        : 0.3836 ± 0.0169
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.5998 ± 0.1205
#   precision : 0.2826 ± 0.1138
#   recall    : 0.7895 ± 0.2785
#   f1        : 0.3824 ± 0.0612
# EXTERNAL METRICS:
#   auroc     : 0.6844 ± 0.1561
#   precision : 0.2844 ± 0.1062
#   recall    : 0.7692 ± 0.2774
#   f1        : 0.3832 ± 0.0557
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6083 ± 0.1296
#   precision : 0.2820 ± 0.1209
#   recall    : 0.8088 ± 0.2497
#   f1        : 0.3871 ± 0.0781
# EXTERNAL METRICS:
#   auroc     : 0.5793 ± 0.1885
#   precision : 0.2660 ± 0.1163
#   recall    : 0.7949 ± 0.2912
#   f1        : 0.3625 ± 0.0578
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 32, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6262 ± 0.1182
#   precision : 0.2539 ± 0.0934
#   recall    : 0.9649 ± 0.0608
#   f1        : 0.3939 ± 0.1050
# EXTERNAL METRICS:
#   auroc     : 0.6054 ± 0.1589
#   precision : 0.2457 ± 0.0870
#   recall    : 0.8974 ± 0.1776
#   f1        : 0.3719 ± 0.0777
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.3735 ± 0.2973
#   precision : 0.2089 ± 0.0419
#   recall    : 0.9825 ± 0.0304
#   f1        : 0.3428 ± 0.0537
# EXTERNAL METRICS:
#   auroc     : 0.4816 ± 0.2709
#   precision : 0.2124 ± 0.0368
#   recall    : 1.0000 ± 0.0000
#   f1        : 0.3494 ± 0.0492
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.5941 ± 0.1206
#   precision : 0.2857 ± 0.1602
#   recall    : 0.8070 ± 0.3343
#   f1        : 0.3641 ± 0.0699
# EXTERNAL METRICS:
#   auroc     : 0.5809 ± 0.1173
#   precision : 0.2673 ± 0.1294
#   recall    : 0.7949 ± 0.3553
#   f1        : 0.3487 ± 0.0445
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 64, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.5712 ± 0.1652
#   precision : 0.2899 ± 0.1820
#   recall    : 0.8421 ± 0.2735
#   f1        : 0.3789 ± 0.1161
# EXTERNAL METRICS:
#   auroc     : 0.5928 ± 0.1686
#   precision : 0.2608 ± 0.1206
#   recall    : 0.8205 ± 0.3109
#   f1        : 0.3568 ± 0.0621
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.7395 ± 0.0964
#   precision : 0.3176 ± 0.2367
#   recall    : 0.8833 ± 0.2021
#   f1        : 0.4107 ± 0.1805
# EXTERNAL METRICS:
#   auroc     : 0.6406 ± 0.1090
#   precision : 0.2813 ± 0.1561
#   recall    : 0.8205 ± 0.3109
#   f1        : 0.3678 ± 0.0811
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 0.0001}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6536 ± 0.0759
#   precision : 0.2954 ± 0.1544
#   recall    : 0.8246 ± 0.3039
#   f1        : 0.3859 ± 0.0762
# EXTERNAL METRICS:
#   auroc     : 0.6494 ± 0.1201
#   precision : 0.2754 ± 0.1224
#   recall    : 0.7949 ± 0.3553
#   f1        : 0.3599 ± 0.0348
# ============================================================
#
# ============================================================
# Hyperparameters: {'dropout': 0.4, 'hidden_dim': 128, 'lr': 1e-05}
# ------------------------------------------------------------
# INTERNAL METRICS:
#   auroc     : 0.6387 ± 0.0953
#   precision : 0.2792 ± 0.1026
#   recall    : 0.8246 ± 0.3039
#   f1        : 0.3854 ± 0.0581
# EXTERNAL METRICS:
#   auroc     : 0.6198 ± 0.1346
#   precision : 0.2950 ± 0.1457
#   recall    : 0.8205 ± 0.3109
#   f1        : 0.3864 ± 0.0708
# ============================================================
#
# {'dropout': 0, 'hidden_dim': 64, 'lr': 0.001}

# %%
from sklearn.metrics import (
    roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix
)
from statistics import mean, stdev
from sklearn.model_selection import RepeatedStratifiedKFold
import numpy as np
import torch, random, torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.calibration import calibration_curve

def run_kfold_crossval_with_external_val(train_dataset, external_val_dataset, k=5, n_repeats=3, optimize_metric='f1'):
    rskf = RepeatedStratifiedKFold(n_splits=k, n_repeats=n_repeats, random_state=SEED)
    labels = train_dataset.labels
    indices = np.arange(len(labels))
    
    fold_aurocs, fold_precisions, fold_recalls, fold_f1s, fold_thresholds = [], [], [], [], []
    external_aurocs, external_precisions, external_recalls, external_f1s = [], [], [], []

    ext_val_loader = DataLoader(external_val_dataset, batch_size=config.BATCH_SIZE)

    for fold, (train_idx, val_idx) in enumerate(rskf.split(indices, labels)):
        print(f"\n===== Fold {fold+1}/{k*n_repeats} =====")

        train_subset = torch.utils.data.Subset(train_dataset, train_idx)
        val_subset = torch.utils.data.Subset(train_dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=config.BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=config.BATCH_SIZE)

        # Reset seeds for reproducibility
        seed = SEED + fold
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        # Build model
        model = SimpleMultimodalNet(clin_dim, mrna_dim, mut_dim).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=config.LEARNING_RATE, weight_decay=1e-5)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

        best_val_auroc = 0
        best_model_state = None
        counter = 0

        # --- Training with early stopping ---
        for epoch in range(config.NUM_EPOCHS):
            model.train()
            for clin, mrna, mut, labels_batch in train_loader:
                clin, mrna, mut, labels_batch = (
                    clin.to(device),
                    mrna.to(device),
                    mut.to(device),
                    labels_batch.to(device),
                )
                optimizer.zero_grad()
                outputs = model(clin, mrna, mut)
                loss = criterion(outputs, labels_batch)
                loss.backward()
                optimizer.step()

            # --- Validation ---
            model.eval()
            all_labels, all_preds = [], []
            with torch.no_grad():
                for clin, mrna, mut, labels_batch in val_loader:
                    clin, mrna, mut, labels_batch = (
                        clin.to(device),
                        mrna.to(device),
                        mut.to(device),
                        labels_batch.to(device),
                    )
                    outputs = model(clin, mrna, mut)
                    all_labels.append(labels_batch.cpu())
                    all_preds.append(torch.sigmoid(outputs).cpu())

            all_labels = torch.cat(all_labels)
            all_preds = torch.cat(all_preds)
            val_auroc = roc_auc_score(all_labels.numpy(), all_preds.numpy())

            if val_auroc > best_val_auroc:
                best_val_auroc = val_auroc
                best_model_state = model.state_dict()
                counter = 0
            else:
                counter += 1
                if counter >= config.PATIENCE:
                    break

        # --- Evaluate best model on its validation fold ---
        model.load_state_dict(best_model_state)
        model.eval()
        all_labels, all_preds = [], []
        with torch.no_grad():
            for clin, mrna, mut, labels_batch in val_loader:
                clin, mrna, mut, labels_batch = (
                    clin.to(device),
                    mrna.to(device),
                    mut.to(device),
                    labels_batch.to(device),
                )
                outputs = model(clin, mrna, mut)
                all_labels.append(labels_batch.cpu())
                all_preds.append(torch.sigmoid(outputs).cpu())

        all_labels = torch.cat(all_labels).numpy()
        all_preds = torch.cat(all_preds).numpy()

        # --- Choose threshold ---
        best_thresh, best_metric = 0.5, -1
        for t in np.linspace(0.001, 0.9, 200):
            pred_labels = (all_preds >= t).astype(float)
            if optimize_metric == 'f1':
                metric_val = f1_score(all_labels, pred_labels, zero_division=0)
            elif optimize_metric == 'youden':
                tn, fp, fn, tp = confusion_matrix(all_labels, pred_labels).ravel()
                sensitivity = tp / (tp + fn + 1e-9)
                specificity = tn / (tn + fp + 1e-9)
                metric_val = sensitivity + specificity - 1
            if metric_val > best_metric:
                best_metric, best_thresh = metric_val, t

        threshold = best_thresh
        fold_thresholds.append(threshold)
        print(f"Selected optimal threshold={threshold:.2f} ({optimize_metric}={best_metric:.4f})")

        # --- Evaluate on *fold validation* set ---
        pred_labels = (all_preds >= threshold).astype(float)
        auroc = roc_auc_score(all_labels, all_preds)
        precision = precision_score(all_labels, pred_labels, zero_division=0)
        recall = recall_score(all_labels, pred_labels, zero_division=0)
        f1 = f1_score(all_labels, pred_labels, zero_division=0)
        fold_aurocs.append(auroc)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_f1s.append(f1)

        print(f"Fold {fold+1} AUROC: {auroc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

        # --- Evaluate best model on *external validation set* ---
        all_labels, all_preds = [], []
        with torch.no_grad():
            for clin, mrna, mut, labels_batch in ext_val_loader:
                clin, mrna, mut, labels_batch = (
                    clin.to(device),
                    mrna.to(device),
                    mut.to(device),
                    labels_batch.to(device),
                )
                outputs = model(clin, mrna, mut)
                all_labels.append(labels_batch.cpu())
                all_preds.append(torch.sigmoid(outputs).cpu())

        all_labels = torch.cat(all_labels).numpy()
        all_preds = torch.cat(all_preds).numpy()
        pred_labels = (all_preds >= threshold).astype(float)

        ext_auroc = roc_auc_score(all_labels, all_preds)
        ext_precision = precision_score(all_labels, pred_labels, zero_division=0)
        ext_recall = recall_score(all_labels, pred_labels, zero_division=0)
        ext_f1 = f1_score(all_labels, pred_labels, zero_division=0)
        external_aurocs.append(ext_auroc)
        external_precisions.append(ext_precision)
        external_recalls.append(ext_recall)
        external_f1s.append(ext_f1)

        print(f"→ External Validation AUROC: {ext_auroc:.4f}, Precision: {ext_precision:.4f}, Recall: {ext_recall:.4f}, F1: {ext_f1:.4f}")

    # --- Summary ---
    print("\n==========================")
    print(" K-Fold Summary (Internal) ")
    print("==========================")
    print(f"Mean AUROC    : {mean(fold_aurocs):.4f} ± {stdev(fold_aurocs):.4f}")
    print(f"Mean Precision: {mean(fold_precisions):.4f} ± {stdev(fold_precisions):.4f}")
    print(f"Mean Recall   : {mean(fold_recalls):.4f} ± {stdev(fold_recalls):.4f}")
    print(f"Mean F1-score : {mean(fold_f1s):.4f} ± {stdev(fold_f1s):.4f}")

    print("\n==========================")
    print(" External Validation Summary ")
    print("==========================")
    print(f"Mean AUROC    : {mean(external_aurocs):.4f} ± {stdev(external_aurocs):.4f}")
    print(f"Mean Precision: {mean(external_precisions):.4f} ± {stdev(external_precisions):.4f}")
    print(f"Mean Recall   : {mean(external_recalls):.4f} ± {stdev(external_recalls):.4f}")
    print(f"Mean F1-score : {mean(external_f1s):.4f} ± {stdev(external_f1s):.4f}")


test_dataset = MultimodalDataset(
    f"{base_dir}/test/clinical.pkl",
    f"{base_dir}/test/mrna.pkl",
    f"{base_dir}/test/mutation.pkl",
    f"{base_dir}/test/labels.pkl"
)

test_loader = DataLoader(test_dataset, batch_size=config.BATCH_SIZE)

run_kfold_crossval_with_external_val(train_dataset, test_dataset,  k=5, n_repeats=3, optimize_metric='f1')
# Out:
# (68, 31)
# (68, 669)
# (68, 411)
#
# ===== Fold 1/15 =====
# Selected optimal threshold=0.90 (f1=0.3380)
# Fold 1 AUROC: 0.7388, Precision: 0.2034, Recall: 1.0000, F1: 0.3380
# → External Validation AUROC: 0.6213, Precision: 0.1803, Recall: 0.9167, F1: 0.3014
#
# ===== Fold 2/15 =====
# Selected optimal threshold=0.01 (f1=0.4167)
# Fold 2 AUROC: 0.6748, Precision: 0.4167, Recall: 0.4167, F1: 0.4167
# → External Validation AUROC: 0.6518, Precision: 0.3846, Recall: 0.4167, F1: 0.4000
#
# ===== Fold 3/15 =====
# Selected optimal threshold=0.08 (f1=0.5294)
# Fold 3 AUROC: 0.7941, Precision: 0.4091, Recall: 0.7500, F1: 0.5294
# → External Validation AUROC: 0.7321, Precision: 0.3571, Recall: 0.4167, F1: 0.3846
#
# ===== Fold 4/15 =====
# Selected optimal threshold=0.09 (f1=0.4667)
# Fold 4 AUROC: 0.7378, Precision: 0.3684, Recall: 0.6364, F1: 0.4667
# → External Validation AUROC: 0.7083, Precision: 0.3182, Recall: 0.5833, F1: 0.4118
#
# ===== Fold 5/15 =====
# Selected optimal threshold=0.81 (f1=0.3014)
# Fold 5 AUROC: 0.6250, Precision: 0.1774, Recall: 1.0000, F1: 0.3014
# → External Validation AUROC: 0.5692, Precision: 0.1765, Recall: 1.0000, F1: 0.3000
#
# ===== Fold 6/15 =====
# Selected optimal threshold=0.80 (f1=0.3380)
# Fold 6 AUROC: 0.8822, Precision: 0.2034, Recall: 1.0000, F1: 0.3380
# → External Validation AUROC: 0.6481, Precision: 0.1719, Recall: 0.9167, F1: 0.2895
#
# ===== Fold 7/15 =====
# Selected optimal threshold=0.74 (f1=0.5000)
# Fold 7 AUROC: 0.7320, Precision: 0.3571, Recall: 0.8333, F1: 0.5000
# → External Validation AUROC: 0.6235, Precision: 0.2400, Recall: 0.5000, F1: 0.3243
#
# ===== Fold 8/15 =====
# Selected optimal threshold=0.28 (f1=0.5926)
# Fold 8 AUROC: 0.8268, Precision: 0.5333, Recall: 0.6667, F1: 0.5926
# → External Validation AUROC: 0.7143, Precision: 0.4545, Recall: 0.4167, F1: 0.4348
#
# ===== Fold 9/15 =====
# Selected optimal threshold=0.77 (f1=0.3056)
# Fold 9 AUROC: 0.6853, Precision: 0.1803, Recall: 1.0000, F1: 0.3056
# → External Validation AUROC: 0.6339, Precision: 0.1765, Recall: 1.0000, F1: 0.3000
#
# ===== Fold 10/15 =====
# Selected optimal threshold=0.88 (f1=0.3188)
# Fold 10 AUROC: 0.4948, Precision: 0.1897, Recall: 1.0000, F1: 0.3188
# → External Validation AUROC: 0.5714, Precision: 0.1846, Recall: 1.0000, F1: 0.3117
#
# ===== Fold 11/15 =====
# Selected optimal threshold=0.89 (f1=0.6000)
# Fold 11 AUROC: 0.7788, Precision: 0.5000, Recall: 0.7500, F1: 0.6000
# → External Validation AUROC: 0.6994, Precision: 0.2727, Recall: 0.2500, F1: 0.2609
#
# ===== Fold 12/15 =====
# Selected optimal threshold=0.78 (f1=0.3333)
# Fold 12 AUROC: 0.7729, Precision: 0.2000, Recall: 1.0000, F1: 0.3333
# → External Validation AUROC: 0.6592, Precision: 0.1765, Recall: 1.0000, F1: 0.3000
#
# ===== Fold 13/15 =====
# Selected optimal threshold=0.83 (f1=0.5333)
# Fold 13 AUROC: 0.8072, Precision: 0.4444, Recall: 0.6667, F1: 0.5333
# → External Validation AUROC: 0.6920, Precision: 0.2941, Recall: 0.4167, F1: 0.3448
#
# ===== Fold 14/15 =====
# Selected optimal threshold=0.02 (f1=0.4091)
# Fold 14 AUROC: 0.6626, Precision: 0.2727, Recall: 0.8182, F1: 0.4091
# → External Validation AUROC: 0.6622, Precision: 0.2353, Recall: 0.6667, F1: 0.3478
#
# ===== Fold 15/15 =====
# Selected optimal threshold=0.60 (f1=0.4865)
# Fold 15 AUROC: 0.7745, Precision: 0.3462, Recall: 0.8182, F1: 0.4865
# → External Validation AUROC: 0.7202, Precision: 0.3478, Recall: 0.6667, F1: 0.4571
#
# ==========================
#  K-Fold Summary (Internal)
# ==========================
# Mean AUROC    : 0.7325 ± 0.0944
# Mean Precision: 0.3201 ± 0.1241
# Mean Recall   : 0.8237 ± 0.1788
# Mean F1-score : 0.4313 ± 0.1058
#
# ==========================
#  External Validation Summary
# ==========================
# Mean AUROC    : 0.6605 ± 0.0511
# Mean Precision: 0.2647 ± 0.0913
# Mean Recall   : 0.6778 ± 0.2707
# Mean F1-score : 0.3446 ± 0.0594

# %% [markdown]
# With dropout = 0:
# Validation AUROC: Mean=0.7799, Std=0.0259
# Test AUROC      : Mean=0.7363, Std=0.0236
# All Validation Runs: [0.8126, 0.7972, 0.772, 0.772, 0.7455]
# All Test Runs       : [0.7083, 0.7664, 0.7411, 0.7173, 0.7485]

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, precision_score, recall_score, accuracy_score

# --- Device setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Load model ---
model.load_state_dict(torch.load("best_model.pth", map_location=device))
model.to(device)
model.eval()

def evaluate_with_threshold(dataloader, threshold, model, device):
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            logits = model(inputs)
            probs = torch.sigmoid(logits).squeeze().detach().cpu()
            labels = labels.detach().cpu()

            all_probs.extend(probs.tolist())
            all_labels.extend(labels.tolist())

    all_probs_tensor = torch.tensor(all_probs)
    all_labels_tensor = torch.tensor(all_labels)

    preds = (all_probs_tensor >= threshold).int()

    auroc = roc_auc_score(all_labels_tensor, all_probs_tensor)
    auprc = average_precision_score(all_labels_tensor, all_probs_tensor)
    f1 = f1_score(all_labels_tensor, preds)
    precision = precision_score(all_labels_tensor, preds)
    recall = recall_score(all_labels_tensor, preds)
    accuracy = accuracy_score(all_labels_tensor, preds)

    return {
        "AUROC": auroc,
        "AUPRC": auprc,
        "F1": f1,
        "Precision": precision,
        "Recall": recall,
        "Accuracy": accuracy
    }

def find_best_threshold(val_loader, model, device):
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for batch in val_loader:
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            logits = model(inputs)
            probs = torch.sigmoid(logits).squeeze().detach().cpu()
            labels = labels.detach().cpu()

            all_probs.extend(probs.tolist())
            all_labels.extend(labels.tolist())

    all_probs_tensor = torch.tensor(all_probs)
    all_labels_tensor = torch.tensor(all_labels)

    thresholds = torch.linspace(0, 1, 101)
    best_f1 = 0.0
    best_thresh = 0.5

    for t in thresholds:
        preds = (all_probs_tensor >= t).int()
        f1 = f1_score(all_labels_tensor, preds)
        if f1 > best_f1:
            best_f1 = f1
            best_thresh = t.item()

    return best_thresh, best_f1

# --- Find best threshold on validation set ---
best_threshold, best_f1 = find_best_threshold(val_loader, model, device)
print(f"\nBest validation F1 threshold: {best_threshold:.3f} (F1 = {best_f1:.3f})")

# --- Evaluate validation metrics ---
val_metrics = evaluate_with_threshold(val_loader, best_threshold, model, device)
print("\nValidation metrics:")
for k, v in val_metrics.items():
    print(f"{k}: {v:.4f}")

# --- Evaluate test metrics ---
test_metrics = evaluate_with_threshold(test_loader, best_threshold, model, device)
print("\nTest metrics (using same threshold):")
for k, v in test_metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# Using device: cuda
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 86
#      83     return best_thresh, best_f1
#      85 # --- Find best threshold on validation set ---
# ---> 86 best_threshold, best_f1 = find_best_threshold(val_loader, model, device)
#      87 print(f"\nBest validation F1 threshold: {best_threshold:.3f} (F1 = {best_f1:.3f})")
#      89 # --- Evaluate validation metrics ---
#
# Cell In[44], line 58, in find_best_threshold(val_loader, model, device)
#      56 with torch.no_grad():
#      57     for batch in val_loader:
# ---> 58         inputs, labels = batch
#      59         inputs = inputs.to(device)
#      60         labels = labels.to(device)
#
# ValueError: too many values to unpack (expected 2)

# %%
state_dict = torch.load("best_model.pth")
model.load_state_dict(state_dict)

# Check the device of model parameters
first_param = next(model.parameters())
print("Model weights are currently on:", first_param.device)
print(device)

model = model.to(device)
model.eval()
all_labels = []
all_probs = []

with torch.no_grad():
    for clin, mrna, mut, labels in val_loader:
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()

        outputs = model(clin, mrna, mut)
        probs = torch.sigmoid(outputs)
        
        all_labels.append(labels)
        all_probs.append(probs)

# Concatenate batches
all_probs = torch.cat(all_probs).cpu().numpy()
all_labels = torch.cat(all_labels).cpu().numpy()

# --- Find optimal threshold based on F1 score ---
thresholds = np.linspace(0, 1, 101)  # 0.00, 0.01, ..., 1.00
f1_scores = []

for t in thresholds:
    preds = (all_probs >= t).astype(float)
    f1 = f1_score(all_labels, preds)
    f1_scores.append(f1)

best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
print(f"Optimal threshold for F1: {best_threshold:.2f}, F1 score: {f1_scores[best_idx]:.4f}")

# Use optimal threshold for predictions
preds = (all_probs >= best_threshold).astype(float)

criterion_bce = nn.BCELoss()


# Metrics
val_loss = np.mean(-all_labels * np.log(all_probs + 1e-8) - (1 - all_labels) * np.log(1 - all_probs + 1e-8))
precision = precision_score(all_labels, preds)
recall = recall_score(all_labels, preds)
auroc = roc_auc_score(all_labels, all_probs)
auprc = average_precision_score(all_labels, all_probs)
cm = confusion_matrix(all_labels, preds)

# Unpack confusion matrix
tn, fp, fn, tp = cm.ravel()

print(f"Validation Loss: {val_loss:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"AUPRC: {auprc:.4f}")
print("Confusion Matrix:")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")


# ---------------------------
# TEST EVALUATION (use best_threshold found on validation)
# ---------------------------

# Ensure model is in eval mode (you already set it, but safe to repeat)
model.eval()

test_labels_list = []
test_probs_list = []

with torch.no_grad():
    for clin, mrna, mut, labels in test_loader:
        # move inputs to device (same as during val)
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()

        outputs = model(clin, mrna, mut)          # logits on device
        probs = torch.sigmoid(outputs)             # probabilities on device

        # collect on CPU
        test_probs_list.append(probs.detach().cpu())
        test_labels_list.append(labels.detach().cpu())

# Concatenate and convert to numpy
test_probs = torch.cat(test_probs_list).numpy()
test_labels = torch.cat(test_labels_list).numpy()

# predictions with the selected threshold
test_preds = (test_probs >= best_threshold).astype(float)

# Compute metrics (AUPRC included), using stable numeric ops
from sklearn.metrics import average_precision_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix

# AUPRC
test_auprc = average_precision_score(test_labels, test_probs)

# AUROC
test_auroc = roc_auc_score(test_labels, test_probs)

# Precision / Recall / F1 at threshold
test_precision = precision_score(test_labels, test_preds, zero_division=0)
test_recall = recall_score(test_labels, test_preds, zero_division=0)
test_f1 = f1_score(test_labels, test_preds, zero_division=0)

# Confusion matrix (tn, fp, fn, tp)
cm = confusion_matrix(test_labels, test_preds)
if cm.size == 4:
    tn, fp, fn, tp = cm.ravel()
else:
    # handle edge cases where only one class present
    tn = fp = fn = tp = 0
    if test_labels.sum() == 0:
        tn = cm.ravel()[0]
    else:
        tp = cm.ravel()[0]

# Test loss (same style as validation: numeric BCElike on probabilities)
eps = 1e-8
test_loss = np.mean(-test_labels * np.log(np.clip(test_probs, eps, 1 - eps)) -
                    (1 - test_labels) * np.log(np.clip(1 - test_probs, eps, 1 - eps)))

# Print test results
print("\n--- Test metrics (using best_threshold from validation) ---")
print(f"Threshold: {best_threshold:.3f}")
print(f"Test Loss (BCE on probs): {test_loss:.6f}")
print(f"AUPRC: {test_auprc:.6f}")
print(f"AUROC: {test_auroc:.6f}")
print(f"Precision: {test_precision:.6f}")
print(f"Recall: {test_recall:.6f}")
print(f"F1: {test_f1:.6f}")
print("Confusion Matrix:")
print(f"  TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
# Out:
# Model weights are currently on: cuda:0
# cuda
# Optimal threshold for F1: 0.96, F1 score: 0.5641
# Validation Loss: 2.1838
# Precision: 0.4231
# Recall: 0.8462
# AUROC: 0.8042
# AUPRC: 0.4901
# Confusion Matrix:
# True Negatives: 40
# False Positives: 15
# False Negatives: 2
# True Positives: 11
#
# --- Test metrics (using best_threshold from validation) ---
# Threshold: 0.960
# Test Loss (BCE on probs): 2.369431
# AUPRC: 0.247429
# AUROC: 0.650298
# Precision: 0.272727
# Recall: 0.750000
# F1: 0.400000
# Confusion Matrix:
#   TN: 32, FP: 24, FN: 3, TP: 9

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

def plot_metrics(y_true, y_scores):
    y_true = y_true.cpu().numpy()
    y_scores = y_scores..cpu().numpy()
    
    # ---------- AUROC ----------
    fpr, tpr, _ = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)
    
    plt.figure(figsize=(12,5))
    
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, color='blue', label=f'AUROC = {roc_auc:.3f}')
    plt.plot([0,1], [0,1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    
    # ----------  AUPRC ----------
    precision, recall, _ = precision_recall_curve(y_true, y_scores)
    ap_score = average_precision_score(y_true, y_scores)
    
    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, color='green', label=f'AUPRC = {ap_score:.3f}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc='lower left')
    
    plt.tight_layout()
    plt.show()

model.eval()
all_labels = []
all_outputs = []
with torch.no_grad():
    for clin, mrna, mut, labels in val_loader:
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()
        
        outputs = model(clin, mrna, mut)
        all_outputs.append(torch.sigmoid(outputs))
        all_labels.append(labels)

all_labels = torch.cat(all_labels)
all_outputs = torch.cat(all_outputs)

plot_metrics(all_labels, all_outputs)

# %%
model.load_state_dict(torch.load("best_model.pth"))
model.eval()
all_labels = []
all_probs = []

with torch.no_grad():
    for clin, mrna, mut, labels in test_loader:
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()

        outputs = model(clin, mrna, mut)
        probs = torch.sigmoid(outputs)
        
        all_labels.append(labels)
        all_probs.append(probs)

# Concatenate batches
all_labels = torch.cat(all_labels).cpu().numpy()
all_probs = torch.cat(all_probs).cpu().numpy()

# --- Find optimal threshold based on F1 score ---
thresholds = np.linspace(0, 1, 101)  # 0.00, 0.01, ..., 1.00
f1_scores = []

for t in thresholds:
    preds = (all_probs >= t).astype(float)
    f1 = f1_score(all_labels, preds)
    f1_scores.append(f1)

best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
print(f"Optimal threshold for F1: {best_threshold:.2f}, F1 score: {f1_scores[best_idx]:.4f}")

# Use optimal threshold for predictions
preds = (all_probs >= best_threshold).astype(float)

# Metrics
test_loss = criterion(torch.tensor(all_probs), torch.tensor(all_labels)).item()
precision = precision_score(all_labels, preds)
recall = recall_score(all_labels, preds)
auroc = roc_auc_score(all_labels, all_probs)
cm = confusion_matrix(all_labels, preds)

# Unpack confusion matrix
tn, fp, fn, tp = cm.ravel()

print(f"Test Loss: {test_loss:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"AUROC: {auroc:.4f}")
print("Confusion Matrix:")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")
# Out:
# Optimal threshold for F1: 0.80, F1 score: 0.4762
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 40
#      37 preds = (all_probs >= best_threshold).astype(float)
#      39 # Metrics
# ---> 40 test_loss = criterion(torch.tensor(all_probs), torch.tensor(all_labels)).item()
#      41 precision = precision_score(all_labels, preds)
#      42 recall = recall_score(all_labels, preds)
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/torch/nn/modules/loss.py:828, in BCEWithLogitsLoss.forward(self, input, target)
#     827 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 828     return F.binary_cross_entropy_with_logits(
#     829         input,
#     830         target,
#     831         self.weight,
#     832         pos_weight=self.pos_weight,
#     833         reduction=self.reduction,
#     834     )
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/torch/nn/functional.py:3597, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3592 if not (target.size() == input.size()):
#    3593     raise ValueError(
#    3594         f"Target size ({target.size()}) must be the same as input size ({input.size()})"
#    3595     )
# -> 3597 return torch.binary_cross_entropy_with_logits(
#    3598     input, target, weight, pos_weight, reduction_enum
#    3599 )
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!
