# %%
# Imports
import os
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import joblib
import random
import pickle
import numpy as np
from statistics import mean, stdev
from sklearn.metrics import roc_auc_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import RepeatedStratifiedKFold
from itertools import product
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import (
    roc_auc_score, precision_score, recall_score, f1_score,
    average_precision_score, confusion_matrix
)
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from statistics import mean, stdev
import numpy as np
import torch, random, torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import config
from preprocessing_utils import *
from model_utils import *

# Set seeds for reproducibility
set_random_seed(42, deterministic=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class MultimodalDataset(Dataset):
    def __init__(self, X, y, clinical_cols, mrna_cols, mutation_cols):
        # Split modalities
        self.clinical = X[clinical_cols].to_numpy()
        self.mrna = X[mrna_cols].to_numpy().astype(float)
        self.mutation = X[mutation_cols].to_numpy().astype(float)
        self.labels = y.to_numpy().astype(float)
                
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return (
            torch.tensor(self.clinical[idx], dtype=torch.float32),
            torch.tensor(self.mrna[idx], dtype=torch.float32),
            torch.tensor(self.mutation[idx], dtype=torch.float32),
            torch.tensor(self.labels[idx], dtype=torch.float32)
        )

# %%
def evaluate_with_threshold(model, loader, threshold):
    model.eval()
    all_probs, all_labels = [], []
    with torch.no_grad():
        for clin, mrna, mut, y in loader:
            clin, mrna, mut, y = clin.to(device), mrna.to(device), mut.to(device), y.to(device)
            probs = torch.sigmoid(model(clin, mrna, mut)).cpu().numpy()
            all_probs.append(probs)
            all_labels.append(y.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    preds = (all_probs >= threshold).astype(float)

    metrics = {
        'auroc': roc_auc_score(all_labels, all_probs),
        'auprc': average_precision_score(all_labels, all_probs),
        'precision': precision_score(all_labels, preds, zero_division=0),
        'recall': recall_score(all_labels, preds, zero_division=0),
        'f1': f1_score(all_labels, preds, zero_division=0)
    }
    return metrics

# %%
X_train = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_train.joblib"))
y_train = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_train.joblib"))
X_val = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_val.joblib"))
y_val = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_val.joblib"))
X_test = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_test.joblib"))
y_test = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_test.joblib"))
clinical_cols = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "clinical_cols.joblib"))
mrna_cols = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "mrna_cols.joblib"))
mutation_cols = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "mutation_cols.joblib"))

X_testval = pd.concat([X_val, X_test], axis=0).reset_index(drop=True)
y_testval = pd.concat([y_val, y_test], axis=0).reset_index(drop=True)

# Split modalities
clinical_train = X_train[clinical_cols]
mrna_train = X_train[mrna_cols]
mutation_train = X_train[mutation_cols]

clinical_val = X_val[clinical_cols]
mrna_val = X_val[mrna_cols]
mutation_val = X_val[mutation_cols]

clinical_test = X_test[clinical_cols]
mrna_test = X_test[mrna_cols]
mutation_test = X_test[mutation_cols]

clinical_testval = X_testval[clinical_cols]
mrna_testval = X_testval[mrna_cols]
mutation_testval = X_testval[mutation_cols]

# %%
def to_loader(c, m, mu, y, shuffle=False):
    import pandas as pd, numpy as np, torch
    from torch.utils.data import TensorDataset, DataLoader

    def ensure_numeric(df):
        if isinstance(df, np.ndarray):
            return df
        return df.to_numpy(dtype=np.float32)
    
    c, m, mu = ensure_numeric(c), ensure_numeric(m), ensure_numeric(mu)
    y = np.array(y, dtype=np.float32).squeeze()
    ds = TensorDataset(
        torch.tensor(c, dtype=torch.float32),
        torch.tensor(m, dtype=torch.float32),
        torch.tensor(mu, dtype=torch.float32),
        torch.tensor(y, dtype=torch.float32)
    )
    return DataLoader(ds, batch_size=config.BATCH_SIZE, shuffle=shuffle)


def apply_preprocessing_and_feature_selection(
    clinical_train, mrna_train, mut_train, y_train,
    clinical_val, mrna_val, mut_val, y_val,
    clinical_test, mrna_test, mut_test, y_test,
    selection_technique, selection_hyperparams,
):
    """
    Applies preprocessing and optional feature selection to clinical, mRNA, and mutation data.
    Works with train, validation, and test splits.
    selection_technique: "logistic_regression" or "none"
    """

    # === Preprocessing ===
    clinical_prep = ClinicalPreprocessorWrapper(
        cols_to_remove=config.CLINICAL_COLS_TO_REMOVE,
        categorical_cols=config.CATEGORICAL_COLS,
        max_null_frac=config.CLINICAL_MAX_NULL_FRAC,
        uniform_thresh=config.CLINICAL_UNIFORM_THRESH,
    )
    mrna_prep = MrnaPreprocessorWrapper(
        max_null_frac=config.MAX_NULL_FRAC,
        uniform_thresh=config.UNIFORM_THRESHOLD,
        corr_thresh=config.CORRELATION_THRESHOLD,
        var_thresh=config.VARIANCE_THRESHOLD,
        re_run_pruning=config.RE_RUN_PRUNING,
        literature_genes=config.LITERATURE_GENES,
        correlated_genes_path=config.CORRELATED_GENES_PATH,
        use_stability_selection=False,
        random_state=config.SEED,
    )
    mut_prep = MutationPreprocessorWrapper(
        max_null_frac=config.MUTATION_MAX_NULL_FRAC,
        uniform_thresh=config.MUTATION_UNIFORM_THRESH,
    )

    # === Fit preprocessors only on training data ===
    clinical_prep.fit(clinical_train)
    mrna_prep.fit(mrna_train, y_train)
    mut_prep.fit(mut_train)

    # === Apply transforms to train/val/test ===
    clin_train = clinical_prep.transform(clinical_train)
    clin_val   = clinical_prep.transform(clinical_val)
    clin_test  = clinical_prep.transform(clinical_test)

    mrna_train = mrna_prep.transform(mrna_train)
    mrna_val   = mrna_prep.transform(mrna_val)
    mrna_test  = mrna_prep.transform(mrna_test)

    mut_train  = mut_prep.transform(mut_train)
    mut_val    = mut_prep.transform(mut_val)
    mut_test   = mut_prep.transform(mut_test)

    # === Feature selection ===
    if selection_technique == "logistic_regression":

        # ---- mRNA feature selection ----
        base_estimator_mrna = selection_hyperparams.get(
            "mrna_model",
            LogisticRegression(penalty="l1", solver="liblinear", max_iter=1000),
        )

        sfm_mrna = SelectFromModel(
            estimator=base_estimator_mrna,
            threshold=selection_hyperparams.get("mrna_threshold", "median"),
        )

        # Align columns before training the selector
        mrna_val  = mrna_val.reindex(columns=mrna_train.columns, fill_value=0)
        mrna_test = mrna_test.reindex(columns=mrna_train.columns, fill_value=0)

        sfm_mrna.fit(mrna_train, y_train)

        mrna_train = sfm_mrna.transform(mrna_train)
        mrna_val   = sfm_mrna.transform(mrna_val)
        mrna_test  = sfm_mrna.transform(mrna_test)

        # ---- Mutation feature selection ----
        base_estimator_mut = selection_hyperparams.get(
            "mut_model",
            LogisticRegression(penalty="l1", solver="liblinear", max_iter=1000),
        )

        sfm_mut = SelectFromModel(
            estimator=base_estimator_mut,
            threshold=selection_hyperparams.get("mut_threshold", "median"),
        )

        mut_val  = mut_val.reindex(columns=mut_train.columns, fill_value=0)
        mut_test = mut_test.reindex(columns=mut_train.columns, fill_value=0)

        sfm_mut.fit(mut_train, y_train)

        mut_train = sfm_mut.transform(mut_train)
        mut_val   = sfm_mut.transform(mut_val)
        mut_test  = sfm_mut.transform(mut_test)

    # === Return everything ===
    return (
        clin_train, mrna_train, mut_train, y_train,
        clin_val,   mrna_val,   mut_val,   y_val,
        clin_test,  mrna_test,  mut_test,  y_test
    )

def retrain_and_evaluate_best_model(
    clin_train, mrna_train, mut_train, y_train,
    clin_test, mrna_test, mut_test, y_test,
    best_hyperparams
):
    """
    Retrains the model using the best hyperparameters on all training data,
    then evaluates on the test data.
    """

    print("\n===== Retraining model with best hyperparameters =====")
    print(best_hyperparams)

    train_loader = to_loader(clin_train, mrna_train, mut_train, y_train, shuffle=True)
    test_loader = to_loader(clin_test, mrna_test, mut_test, y_test)

    # === Model ===
    # model = MultimodalNet(
    #     clin_train.shape[1], mrna_train.shape[1], mut_train.shape[1],
    #     use_gene_sel=True
    # ).to(device)
    model = MultimodalNet(
        clin_train.shape[1], mrna_train.shape[1], mut_train.shape[1]
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=best_hyperparams.get('lr', 1e-3))
    pos_weight_value = torch.tensor((len(y_train) - y_train.sum()) / y_train.sum(), dtype=torch.float32).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_value)

    # === Training ===
    print("Training final model...")
    best_state = train_one_fold(train_loader, test_loader, model, optimizer, criterion, config.SEED, verbose="True", device=device)
    model.load_state_dict(best_state)

    # === Tune threshold on training set ===
    all_probs, all_labels = [], []
    with torch.no_grad():
        for clin, mrna, mut, y in train_loader:
            clin, mrna, mut, y = clin.to(device), mrna.to(device), mut.to(device), y.to(device)
            probs = torch.sigmoid(model(clin, mrna, mut)).cpu().numpy()
            all_probs.append(probs)
            all_labels.append(y.cpu().numpy())
    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)

    thresholds = np.linspace(0.001, 0.9, 200)
    best_t, best_metric = 0.5, -1
    for t in thresholds:
        preds = (all_probs >= t).astype(float)
        score = f1_score(all_labels, preds, zero_division=0)
        if score > best_metric:
            best_metric, best_t = score, t

    print(f"Best threshold from training: {best_t:.3f}")

    # === Final evaluation ===
    test_metrics = evaluate_with_threshold(model, test_loader, best_t)
    print(f"\nFinal test metrics: {test_metrics}")

    return model, test_metrics, best_t

# %%
clinical_train, mrna_train, mutation_train, y_train, clinical_val, mrna_val, mutation_val, y_val, clinical_test, mrna_test, mutation_test, y_test = apply_preprocessing_and_feature_selection(
    clinical_train, mrna_train, mutation_train, y_train,
    clinical_val, mrna_val, mutation_val, y_val,
    clinical_test, mrna_test, mutation_test, y_test,
    'none', {}
)

# %%
# =======================
# Neural Network
# =======================
class MultimodalNet(nn.Module):
    def __init__(self,
                 clin_dim, mrna_dim, mut_dim,
                 clin_hidden=[64, 32],
                 mrna_hidden=[64, 32],
                 mut_hidden=[64, 32],
                 clin_dropout=[0, 0],
                 mrna_dropout=[0, 0],
                 mut_dropout=[0, 0],
                 activation='relu',
                 fusion_hidden=64,
                 fusion_dropout=0,
                 use_gene_sel=True,
                ):
        super().__init__()
        
        self.use_gene_sel = use_gene_sel
        if use_gene_sel:
            # ===== Gene selectors (for omics modalities) =====
            self.gene_sel_mrna = GeneSelector(mrna_dim)
            self.gene_sel_mut = GeneSelector(mut_dim)

        # ===== Modality encoders =====
        self.enc_clin = ModalityEncoder(clin_dim, clin_hidden, clin_dropout, activation)
        self.enc_mrna = ModalityEncoder(mrna_dim, mrna_hidden, mrna_dropout, activation)
        self.enc_mut  = ModalityEncoder(mut_dim, mut_hidden, mut_dropout, activation)


        # ===== Fusion + final classifier =====
        total_dim = clin_hidden[-1] + mrna_hidden[-1] + mut_hidden[-1]
        self.fusion_fc = nn.Sequential(
            nn.Linear(total_dim, fusion_hidden),
            nn.ReLU(),
            nn.Dropout(fusion_dropout),
            nn.Linear(fusion_hidden, 1)
        )
        
    def forward(self, clin, mrna, mut):
        if self.use_gene_sel:
            # Apply gene selectors
            mrna = self.gene_sel_mrna(mrna)
            mut = self.gene_sel_mut(mut)

        # Encode each modality
        clin_emb = self.enc_clin(clin)
        mrna_emb = self.enc_mrna(mrna)
        mut_emb  = self.enc_mut(mut)
        
        # Fuse and classify
        fused = torch.cat([clin_emb, mrna_emb, mut_emb], dim=1)
        output = self.fusion_fc(fused)
        return output.squeeze()

# %%
class SimpleMultimodalNet(nn.Module):
    def __init__(self, clin_dim, mrna_dim, mut_dim, hidden_dim, dropout, lr):
        super().__init__()

        # Separate encoders for each modality
        self.clinical_fc = nn.Sequential(
            nn.Linear(clin_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        self.mrna_fc = nn.Sequential(
            nn.Linear(mrna_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        self.mut_fc = nn.Sequential(
            nn.Linear(mut_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        # Fusion layer
        self.fusion_fc = nn.Sequential(
            nn.Linear(hidden_dim * 3, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1),  # Binary output
        )

    def forward(self, clin, mrna, mut, target_data=None):
        """
        Forward pass. If target_data is provided, also computes CORAL loss.
        target_data should be a tuple: (clin_t, mrna_t, mut_t)
        """
        clin_emb = self.clinical_fc(clin)
        mrna_emb = self.mrna_fc(mrna)
        mut_emb = self.mut_fc(mut)

        fused_source = torch.cat([clin_emb, mrna_emb, mut_emb], dim=1)
        output = self.fusion_fc(fused_source).squeeze()

        # If no target data, just return output
        if target_data is None:
            return output, None

        # Compute target embeddings for CORAL loss
        clin_t, mrna_t, mut_t = target_data
        clin_emb_t = self.clinical_fc(clin_t)
        mrna_emb_t = self.mrna_fc(mrna_t)
        mut_emb_t = self.mut_fc(mut_t)
        fused_target = torch.cat([clin_emb_t, mrna_emb_t, mut_emb_t], dim=1)

        # Compute CORAL loss between source and target fused features
        coral_loss = coral_loss_fn(fused_source, fused_target)

        return output, coral_loss

# %%
best_hyperparams = {'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05} # CHANGE

model, test_metrics, best_t = retrain_and_evaluate_best_model(
    clinical_train, mrna_train, mutation_train, y_train,
    clinical_val, mrna_val, mutation_val, y_val,
    best_hyperparams
)

print("\n=== Final Test Results ===")
for metric, value in test_metrics.items():
    print(f"{metric}: {value:.4f}")

print(f"Optimal threshold: {best_t:.3f}")
# Out:
# ===== Retraining model with best hyperparameters =====
# {'dropout': 0, 'hidden_dim': 64, 'lr': 1e-05}
# Training final model...
# Epoch 001 | Train Loss: 0.8842 | Val AUROC: 0.5385 | P: 0.375 | R: 1.000 | F1: 0.545 | TN: 0 | FP: 40 | FN: 0 | TP: 24
# Epoch 002 | Train Loss: 0.8456 | Val AUROC: 0.5948 | P: 0.387 | R: 1.000 | F1: 0.558 | TN: 2 | FP: 38 | FN: 0 | TP: 24
# Epoch 003 | Train Loss: 0.8134 | Val AUROC: 0.6302 | P: 0.414 | R: 1.000 | F1: 0.585 | TN: 6 | FP: 34 | FN: 0 | TP: 24
# Epoch 004 | Train Loss: 0.7912 | Val AUROC: 0.6552 | P: 0.429 | R: 1.000 | F1: 0.600 | TN: 8 | FP: 32 | FN: 0 | TP: 24
# Epoch 005 | Train Loss: 0.7738 | Val AUROC: 0.6708 | P: 0.436 | R: 1.000 | F1: 0.608 | TN: 9 | FP: 31 | FN: 0 | TP: 24
# Epoch 006 | Train Loss: 0.7536 | Val AUROC: 0.6844 | P: 0.436 | R: 1.000 | F1: 0.608 | TN: 9 | FP: 31 | FN: 0 | TP: 24
# Epoch 007 | Train Loss: 0.7441 | Val AUROC: 0.6979 | P: 0.426 | R: 0.958 | F1: 0.590 | TN: 9 | FP: 31 | FN: 1 | TP: 23
# Epoch 008 | Train Loss: 0.7266 | Val AUROC: 0.7073 | P: 0.438 | R: 0.875 | F1: 0.583 | TN: 13 | FP: 27 | FN: 3 | TP: 21
# Epoch 009 | Train Loss: 0.7121 | Val AUROC: 0.7177 | P: 0.457 | R: 0.875 | F1: 0.600 | TN: 15 | FP: 25 | FN: 3 | TP: 21
# Epoch 010 | Train Loss: 0.6992 | Val AUROC: 0.7323 | P: 0.488 | R: 0.875 | F1: 0.627 | TN: 18 | FP: 22 | FN: 3 | TP: 21
# Epoch 011 | Train Loss: 0.6939 | Val AUROC: 0.7385 | P: 0.488 | R: 0.875 | F1: 0.627 | TN: 18 | FP: 22 | FN: 3 | TP: 21
# Epoch 012 | Train Loss: 0.6814 | Val AUROC: 0.7333 | P: 0.512 | R: 0.875 | F1: 0.646 | TN: 20 | FP: 20 | FN: 3 | TP: 21
# Epoch 013 | Train Loss: 0.6706 | Val AUROC: 0.7313 | P: 0.525 | R: 0.875 | F1: 0.656 | TN: 21 | FP: 19 | FN: 3 | TP: 21
# Epoch 014 | Train Loss: 0.6615 | Val AUROC: 0.7333 | P: 0.538 | R: 0.875 | F1: 0.667 | TN: 22 | FP: 18 | FN: 3 | TP: 21
# Epoch 015 | Train Loss: 0.6541 | Val AUROC: 0.7323 | P: 0.553 | R: 0.875 | F1: 0.677 | TN: 23 | FP: 17 | FN: 3 | TP: 21
# Epoch 016 | Train Loss: 0.6491 | Val AUROC: 0.7302 | P: 0.553 | R: 0.875 | F1: 0.677 | TN: 23 | FP: 17 | FN: 3 | TP: 21
# Epoch 017 | Train Loss: 0.6338 | Val AUROC: 0.7271 | P: 0.568 | R: 0.875 | F1: 0.689 | TN: 24 | FP: 16 | FN: 3 | TP: 21
# Epoch 018 | Train Loss: 0.6307 | Val AUROC: 0.7271 | P: 0.556 | R: 0.833 | F1: 0.667 | TN: 24 | FP: 16 | FN: 4 | TP: 20
# Epoch 019 | Train Loss: 0.6193 | Val AUROC: 0.7302 | P: 0.556 | R: 0.833 | F1: 0.667 | TN: 24 | FP: 16 | FN: 4 | TP: 20
# Epoch 020 | Train Loss: 0.6149 | Val AUROC: 0.7302 | P: 0.543 | R: 0.792 | F1: 0.644 | TN: 24 | FP: 16 | FN: 5 | TP: 19
# Epoch 021 | Train Loss: 0.6121 | Val AUROC: 0.7302 | P: 0.543 | R: 0.792 | F1: 0.644 | TN: 24 | FP: 16 | FN: 5 | TP: 19
# Epoch 022 | Train Loss: 0.6035 | Val AUROC: 0.7302 | P: 0.559 | R: 0.792 | F1: 0.655 | TN: 25 | FP: 15 | FN: 5 | TP: 19
# Epoch 023 | Train Loss: 0.5952 | Val AUROC: 0.7333 | P: 0.559 | R: 0.792 | F1: 0.655 | TN: 25 | FP: 15 | FN: 5 | TP: 19
# Epoch 024 | Train Loss: 0.5932 | Val AUROC: 0.7344 | P: 0.559 | R: 0.792 | F1: 0.655 | TN: 25 | FP: 15 | FN: 5 | TP: 19
# Epoch 025 | Train Loss: 0.5870 | Val AUROC: 0.7333 | P: 0.559 | R: 0.792 | F1: 0.655 | TN: 25 | FP: 15 | FN: 5 | TP: 19
# Epoch 026 | Train Loss: 0.5817 | Val AUROC: 0.7333 | P: 0.545 | R: 0.750 | F1: 0.632 | TN: 25 | FP: 15 | FN: 6 | TP: 18
# Epoch 027 | Train Loss: 0.5793 | Val AUROC: 0.7354 | P: 0.545 | R: 0.750 | F1: 0.632 | TN: 25 | FP: 15 | FN: 6 | TP: 18
# Epoch 028 | Train Loss: 0.5693 | Val AUROC: 0.7375 | P: 0.545 | R: 0.750 | F1: 0.632 | TN: 25 | FP: 15 | FN: 6 | TP: 18
# Epoch 029 | Train Loss: 0.5656 | Val AUROC: 0.7344 | P: 0.545 | R: 0.750 | F1: 0.632 | TN: 25 | FP: 15 | FN: 6 | TP: 18
# Epoch 030 | Train Loss: 0.5631 | Val AUROC: 0.7354 | P: 0.545 | R: 0.750 | F1: 0.632 | TN: 25 | FP: 15 | FN: 6 | TP: 18
# Epoch 031 | Train Loss: 0.5590 | Val AUROC: 0.7385 | P: 0.531 | R: 0.708 | F1: 0.607 | TN: 25 | FP: 15 | FN: 7 | TP: 17
# Epoch 032 | Train Loss: 0.5499 | Val AUROC: 0.7406 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 033 | Train Loss: 0.5495 | Val AUROC: 0.7396 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 034 | Train Loss: 0.5465 | Val AUROC: 0.7406 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 035 | Train Loss: 0.5373 | Val AUROC: 0.7406 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 036 | Train Loss: 0.5383 | Val AUROC: 0.7385 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 037 | Train Loss: 0.5325 | Val AUROC: 0.7385 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 038 | Train Loss: 0.5320 | Val AUROC: 0.7396 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 039 | Train Loss: 0.5266 | Val AUROC: 0.7406 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 040 | Train Loss: 0.5246 | Val AUROC: 0.7437 | P: 0.516 | R: 0.667 | F1: 0.582 | TN: 25 | FP: 15 | FN: 8 | TP: 16
# Epoch 041 | Train Loss: 0.5213 | Val AUROC: 0.7448 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 042 | Train Loss: 0.5186 | Val AUROC: 0.7448 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 043 | Train Loss: 0.5133 | Val AUROC: 0.7396 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 044 | Train Loss: 0.5103 | Val AUROC: 0.7458 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 045 | Train Loss: 0.5070 | Val AUROC: 0.7448 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 046 | Train Loss: 0.4999 | Val AUROC: 0.7448 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 047 | Train Loss: 0.5062 | Val AUROC: 0.7458 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 048 | Train Loss: 0.4965 | Val AUROC: 0.7458 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 049 | Train Loss: 0.4968 | Val AUROC: 0.7438 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 050 | Train Loss: 0.4901 | Val AUROC: 0.7417 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 051 | Train Loss: 0.4902 | Val AUROC: 0.7417 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 052 | Train Loss: 0.4850 | Val AUROC: 0.7417 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 053 | Train Loss: 0.4842 | Val AUROC: 0.7427 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 054 | Train Loss: 0.4813 | Val AUROC: 0.7427 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 055 | Train Loss: 0.4802 | Val AUROC: 0.7437 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 056 | Train Loss: 0.4759 | Val AUROC: 0.7427 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 057 | Train Loss: 0.4723 | Val AUROC: 0.7427 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 058 | Train Loss: 0.4691 | Val AUROC: 0.7458 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 059 | Train Loss: 0.4692 | Val AUROC: 0.7458 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 060 | Train Loss: 0.4680 | Val AUROC: 0.7448 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 061 | Train Loss: 0.4638 | Val AUROC: 0.7479 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 062 | Train Loss: 0.4614 | Val AUROC: 0.7490 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 063 | Train Loss: 0.4574 | Val AUROC: 0.7479 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 064 | Train Loss: 0.4579 | Val AUROC: 0.7490 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 065 | Train Loss: 0.4523 | Val AUROC: 0.7469 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 066 | Train Loss: 0.4525 | Val AUROC: 0.7469 | P: 0.517 | R: 0.625 | F1: 0.566 | TN: 26 | FP: 14 | FN: 9 | TP: 15
# Epoch 067 | Train Loss: 0.4480 | Val AUROC: 0.7469 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 068 | Train Loss: 0.4412 | Val AUROC: 0.7448 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 069 | Train Loss: 0.4441 | Val AUROC: 0.7417 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 070 | Train Loss: 0.4424 | Val AUROC: 0.7417 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 071 | Train Loss: 0.4394 | Val AUROC: 0.7417 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 072 | Train Loss: 0.4333 | Val AUROC: 0.7427 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 073 | Train Loss: 0.4359 | Val AUROC: 0.7417 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 074 | Train Loss: 0.4276 | Val AUROC: 0.7427 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 075 | Train Loss: 0.4305 | Val AUROC: 0.7448 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 076 | Train Loss: 0.4263 | Val AUROC: 0.7458 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 077 | Train Loss: 0.4250 | Val AUROC: 0.7479 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 078 | Train Loss: 0.4200 | Val AUROC: 0.7490 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 079 | Train Loss: 0.4218 | Val AUROC: 0.7490 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 080 | Train Loss: 0.4168 | Val AUROC: 0.7510 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 081 | Train Loss: 0.4191 | Val AUROC: 0.7500 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 082 | Train Loss: 0.4154 | Val AUROC: 0.7521 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 083 | Train Loss: 0.4112 | Val AUROC: 0.7510 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 084 | Train Loss: 0.4051 | Val AUROC: 0.7490 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 085 | Train Loss: 0.4045 | Val AUROC: 0.7490 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 086 | Train Loss: 0.4033 | Val AUROC: 0.7510 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 087 | Train Loss: 0.4045 | Val AUROC: 0.7510 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 088 | Train Loss: 0.4009 | Val AUROC: 0.7500 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 089 | Train Loss: 0.3986 | Val AUROC: 0.7490 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 090 | Train Loss: 0.4003 | Val AUROC: 0.7500 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 091 | Train Loss: 0.3953 | Val AUROC: 0.7500 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 092 | Train Loss: 0.3955 | Val AUROC: 0.7500 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 093 | Train Loss: 0.3926 | Val AUROC: 0.7500 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 094 | Train Loss: 0.3921 | Val AUROC: 0.7510 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 095 | Train Loss: 0.3870 | Val AUROC: 0.7521 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 096 | Train Loss: 0.3853 | Val AUROC: 0.7531 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 097 | Train Loss: 0.3842 | Val AUROC: 0.7562 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 098 | Train Loss: 0.3862 | Val AUROC: 0.7562 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 099 | Train Loss: 0.3835 | Val AUROC: 0.7562 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 100 | Train Loss: 0.3776 | Val AUROC: 0.7573 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 101 | Train Loss: 0.3750 | Val AUROC: 0.7573 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 102 | Train Loss: 0.3765 | Val AUROC: 0.7573 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 103 | Train Loss: 0.3762 | Val AUROC: 0.7573 | P: 0.552 | R: 0.667 | F1: 0.604 | TN: 27 | FP: 13 | FN: 8 | TP: 16
# Epoch 104 | Train Loss: 0.3712 | Val AUROC: 0.7562 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 105 | Train Loss: 0.3706 | Val AUROC: 0.7542 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 106 | Train Loss: 0.3709 | Val AUROC: 0.7562 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 107 | Train Loss: 0.3655 | Val AUROC: 0.7562 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 108 | Train Loss: 0.3658 | Val AUROC: 0.7521 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 109 | Train Loss: 0.3643 | Val AUROC: 0.7531 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 110 | Train Loss: 0.3618 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 111 | Train Loss: 0.3607 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 112 | Train Loss: 0.3569 | Val AUROC: 0.7510 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 113 | Train Loss: 0.3586 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 114 | Train Loss: 0.3557 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 115 | Train Loss: 0.3561 | Val AUROC: 0.7542 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 116 | Train Loss: 0.3529 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 117 | Train Loss: 0.3473 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 118 | Train Loss: 0.3504 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 119 | Train Loss: 0.3488 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 120 | Train Loss: 0.3502 | Val AUROC: 0.7542 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 121 | Train Loss: 0.3437 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 122 | Train Loss: 0.3426 | Val AUROC: 0.7510 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 123 | Train Loss: 0.3414 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 124 | Train Loss: 0.3386 | Val AUROC: 0.7604 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 125 | Train Loss: 0.3361 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 126 | Train Loss: 0.3354 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 127 | Train Loss: 0.3322 | Val AUROC: 0.7542 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 128 | Train Loss: 0.3318 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 129 | Train Loss: 0.3305 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 130 | Train Loss: 0.3303 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 131 | Train Loss: 0.3276 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 132 | Train Loss: 0.3270 | Val AUROC: 0.7542 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 133 | Train Loss: 0.3248 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 134 | Train Loss: 0.3213 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 135 | Train Loss: 0.3224 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 136 | Train Loss: 0.3183 | Val AUROC: 0.7583 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 137 | Train Loss: 0.3194 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 138 | Train Loss: 0.3171 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 139 | Train Loss: 0.3155 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 140 | Train Loss: 0.3137 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 141 | Train Loss: 0.3100 | Val AUROC: 0.7583 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 142 | Train Loss: 0.3128 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 143 | Train Loss: 0.3089 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 144 | Train Loss: 0.3085 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 145 | Train Loss: 0.3065 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 146 | Train Loss: 0.3069 | Val AUROC: 0.7583 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 147 | Train Loss: 0.3024 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 148 | Train Loss: 0.3019 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 149 | Train Loss: 0.2987 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 150 | Train Loss: 0.2989 | Val AUROC: 0.7583 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 151 | Train Loss: 0.2968 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 152 | Train Loss: 0.2984 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 153 | Train Loss: 0.2962 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 154 | Train Loss: 0.2926 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 155 | Train Loss: 0.2911 | Val AUROC: 0.7542 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 156 | Train Loss: 0.2893 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 157 | Train Loss: 0.2903 | Val AUROC: 0.7573 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 158 | Train Loss: 0.2879 | Val AUROC: 0.7563 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 159 | Train Loss: 0.2858 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 160 | Train Loss: 0.2839 | Val AUROC: 0.7563 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 161 | Train Loss: 0.2831 | Val AUROC: 0.7562 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 162 | Train Loss: 0.2799 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 163 | Train Loss: 0.2824 | Val AUROC: 0.7552 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 164 | Train Loss: 0.2774 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 165 | Train Loss: 0.2808 | Val AUROC: 0.7510 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 166 | Train Loss: 0.2793 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 167 | Train Loss: 0.2747 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 168 | Train Loss: 0.2747 | Val AUROC: 0.7510 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 169 | Train Loss: 0.2737 | Val AUROC: 0.7500 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 170 | Train Loss: 0.2699 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 171 | Train Loss: 0.2698 | Val AUROC: 0.7500 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 172 | Train Loss: 0.2682 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 173 | Train Loss: 0.2698 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 174 | Train Loss: 0.2673 | Val AUROC: 0.7500 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 175 | Train Loss: 0.2654 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 176 | Train Loss: 0.2649 | Val AUROC: 0.7531 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 177 | Train Loss: 0.2651 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 178 | Train Loss: 0.2620 | Val AUROC: 0.7510 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 179 | Train Loss: 0.2601 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 180 | Train Loss: 0.2597 | Val AUROC: 0.7448 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 181 | Train Loss: 0.2594 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 182 | Train Loss: 0.2599 | Val AUROC: 0.7521 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 183 | Train Loss: 0.2576 | Val AUROC: 0.7500 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 184 | Train Loss: 0.2552 | Val AUROC: 0.7500 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 185 | Train Loss: 0.2537 | Val AUROC: 0.7510 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 186 | Train Loss: 0.2534 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 187 | Train Loss: 0.2520 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 188 | Train Loss: 0.2499 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 189 | Train Loss: 0.2504 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 190 | Train Loss: 0.2484 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 191 | Train Loss: 0.2461 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 192 | Train Loss: 0.2464 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 193 | Train Loss: 0.2455 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 194 | Train Loss: 0.2433 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 195 | Train Loss: 0.2417 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 196 | Train Loss: 0.2413 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 197 | Train Loss: 0.2414 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 198 | Train Loss: 0.2412 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 199 | Train Loss: 0.2392 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 200 | Train Loss: 0.2372 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 201 | Train Loss: 0.2370 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 202 | Train Loss: 0.2351 | Val AUROC: 0.7448 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 203 | Train Loss: 0.2345 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 204 | Train Loss: 0.2321 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 205 | Train Loss: 0.2338 | Val AUROC: 0.7438 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 206 | Train Loss: 0.2311 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 207 | Train Loss: 0.2303 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 208 | Train Loss: 0.2288 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 209 | Train Loss: 0.2283 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 210 | Train Loss: 0.2273 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 211 | Train Loss: 0.2269 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 212 | Train Loss: 0.2249 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 213 | Train Loss: 0.2255 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 214 | Train Loss: 0.2247 | Val AUROC: 0.7448 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 215 | Train Loss: 0.2235 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 216 | Train Loss: 0.2216 | Val AUROC: 0.7458 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 217 | Train Loss: 0.2220 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 218 | Train Loss: 0.2200 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 219 | Train Loss: 0.2183 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 220 | Train Loss: 0.2186 | Val AUROC: 0.7490 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 221 | Train Loss: 0.2176 | Val AUROC: 0.7479 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Epoch 222 | Train Loss: 0.2150 | Val AUROC: 0.7448 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 223 | Train Loss: 0.2146 | Val AUROC: 0.7458 | P: 0.536 | R: 0.625 | F1: 0.577 | TN: 27 | FP: 13 | FN: 9 | TP: 15
# Epoch 224 | Train Loss: 0.2133 | Val AUROC: 0.7469 | P: 0.556 | R: 0.625 | F1: 0.588 | TN: 28 | FP: 12 | FN: 9 | TP: 15
# Early stopping at epoch 224 (patience=100)
# Best threshold from training: 0.231
#
# Final test metrics: {'auroc': 0.746875, 'auprc': 0.5804324290179204, 'precision': 0.375, 'recall': 1.0, 'f1': 0.5454545454545454}
#
# === Final Test Results ===
# auroc: 0.7469
# auprc: 0.5804
# precision: 0.3750
# recall: 1.0000
# f1: 0.5455
# Optimal threshold: 0.231

# %%
val_loader = to_loader(clinical_val, mrna_val, mutation_val, y_val)

model.eval()
all_labels = []
all_probs = []

with torch.no_grad():
    for clin, mrna, mut, labels in test_loader:
        clin = clin.to(device, non_blocking=True)
        mrna = mrna.to(device, non_blocking=True)
        mut = mut.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True).float()

        outputs = model(clin, mrna, mut)
        probs = torch.sigmoid(outputs)
        
        all_labels.append(labels)
        all_probs.append(probs)

# Concatenate batches
all_labels = torch.cat(all_labels).cpu().numpy()
all_probs = torch.cat(all_probs).cpu().numpy()

# --- Find optimal threshold based on F1 score ---
thresholds = np.linspace(0, 1, 101)  # 0.00, 0.01, ..., 1.00
f1_scores = []

for t in thresholds:
    preds = (all_probs >= t).astype(float)
    f1 = f1_score(all_labels, preds)
    f1_scores.append(f1)

best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
print(f"Optimal threshold for F1: {best_threshold:.2f}, F1 score: {f1_scores[best_idx]:.4f}")

# Use optimal threshold for predictions
preds = (all_probs >= best_threshold).astype(float)

# Metrics
precision = precision_score(all_labels, preds)
recall = recall_score(all_labels, preds)
auroc = roc_auc_score(all_labels, all_probs)
cm = confusion_matrix(all_labels, preds)

# Unpack confusion matrix
tn, fp, fn, tp = cm.ravel()

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"AUROC: {auroc:.4f}")
print("Confusion Matrix:")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 val_loader = to_loader(clinical_val, mrna_val, mutation_val, y_val)
# ----> 2 test_loader = to_loader(clinical_test, mrna_test, mutation_test, y_test)
#       4 model.eval()
#       5 all_labels = []
#
# Cell In[5], line 10, in to_loader(c, m, mu, y, shuffle)
#       7         return df
#       8     return df.to_numpy(dtype=np.float32)
# ---> 10 c, m, mu = ensure_numeric(c), ensure_numeric(m), ensure_numeric(mu)
#      11 y = np.array(y, dtype=np.float32).squeeze()
#      12 ds = TensorDataset(
#      13     torch.tensor(c, dtype=torch.float32),
#      14     torch.tensor(m, dtype=torch.float32),
#      15     torch.tensor(mu, dtype=torch.float32),
#      16     torch.tensor(y, dtype=torch.float32)
#      17 )
#
# Cell In[5], line 8, in to_loader.<locals>.ensure_numeric(df)
#       6 if isinstance(df, np.ndarray):
#       7     return df
# ----> 8 return df.to_numpy(dtype=np.float32)
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/pandas/core/frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/pandas/core/internals/managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File /oscar/home/gchermsi/newenv-py/lib/python3.11/site-packages/pandas/core/internals/managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'UCEC_MSI'
