# %%
import joblib
import os
import matplotlib.pyplot as plt
import numpy as np
import config

from sklearn.metrics import (
    roc_auc_score, roc_curve,
    confusion_matrix, precision_score, recall_score
)

# %%
# Path to your saved artifacts
output_dir = "../models/lasso_bootstrapped_selectkbest_grid_search"

# Load everything
best_model = joblib.load(os.path.join(output_dir, "lasso_model.joblib"))
grid_search = joblib.load(os.path.join(output_dir, "lasso_gridsearch.joblib"))
X_train = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_train.joblib"))
y_train = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_train.joblib"))
X_val = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_val.joblib"))
y_val = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_val.joblib"))
X_test = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "X_test.joblib"))
y_test = joblib.load(os.path.join(config.SPLIT_DATA_DIR, "y_test.joblib"))

print("All artifacts loaded successfully!")
print("Best parameters:", grid_search.best_params_)
# Out:
# All artifacts loaded successfully!
# Best parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}

# %%
# cv_results = grid_search.cv_results_

# mean_test_scores = cv_results['mean_test_score']
# std_test_scores = cv_results['std_test_score']
# params = cv_results['params']

# print("Grid Search Results:\n")
# for mean, std, param in zip(mean_test_scores, std_test_scores, params):
#     print(f"Parameters: {param}")
#     print(f"Mean AUC-ROC: {mean:.4f} ± {std:.4f}")
#     print("-" * 40)

cv_results = grid_search.cv_results_

mean_test_scores = cv_results['mean_test_score']
std_test_scores = cv_results['std_test_score']
params = cv_results['params']

print("Grid Search Results:\n")
for mean, std, param in zip(mean_test_scores, std_test_scores, params):
    print(f"Parameters: {param}")
    print(f"Mean AUC-ROC: {mean:.4f} ± {std:.4f}")
    print("-" * 40)

# Print best combination
print("\nBest Model Summary:")
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Mean AUC-ROC: {grid_search.best_score_:.4f}")
# Out:
# Grid Search Results:
#
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.01, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5000 ± 0.0000
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5200 ± 0.0765
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5030 ± 0.0461
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.4935 ± 0.0661
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5604 ± 0.0273
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5867 ± 0.0429
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5679 ± 0.0340
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.4834 ± 0.0773
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5658 ± 0.0355
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5480 ± 0.0956
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5732 ± 0.0734
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5883 ± 0.0642
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.4922 ± 0.0646
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5190 ± 0.1083
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5058 ± 0.0930
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5504 ± 0.0534
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5130 ± 0.0260
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5333 ± 0.0321
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5537 ± 0.0614
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4748 ± 0.0657
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4999 ± 0.0852
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5349 ± 0.0866
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5299 ± 0.0303
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5199 ± 0.0218
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4747 ± 0.0708
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5105 ± 0.0983
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5497 ± 0.0544
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5577 ± 0.0337
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5336 ± 0.0120
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5287 ± 0.1201
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5172 ± 0.1247
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5366 ± 0.0359
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5495 ± 0.0531
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5624 ± 0.0582
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5487 ± 0.0937
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5242 ± 0.0856
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5636 ± 0.0619
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5738 ± 0.0749
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5621 ± 0.0492
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5409 ± 0.0070
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5312 ± 0.0200
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5510 ± 0.0621
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5649 ± 0.0550
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5372 ± 0.0199
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5340 ± 0.0145
# ----------------------------------------
# Parameters: {'clf__C': 0.1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5401 ± 0.1346
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5259 ± 0.0570
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.4856 ± 0.0160
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.4911 ± 0.0404
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5384 ± 0.0647
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5539 ± 0.0530
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5322 ± 0.0215
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5491 ± 0.0155
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5151 ± 0.1009
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4753 ± 0.0709
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5200 ± 0.0415
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5542 ± 0.0538
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5301 ± 0.0177
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5240 ± 0.1112
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5563 ± 0.0592
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5354 ± 0.0614
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5584 ± 0.0423
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5617 ± 0.0514
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5218 ± 0.0316
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5567 ± 0.0035
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4753 ± 0.0709
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5594 ± 0.0518
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5646 ± 0.0374
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5524 ± 0.0116
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4889 ± 0.0747
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.6093 ± 0.0545
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5809 ± 0.0573
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5242 ± 0.0296
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5332 ± 0.0139
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4909 ± 0.0764
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5592 ± 0.0527
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5244 ± 0.0461
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5994 ± 0.0452
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5475 ± 0.0764
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5455 ± 0.0125
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5200 ± 0.0467
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5098 ± 0.0596
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5753 ± 0.0575
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5344 ± 0.0527
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5319 ± 0.0186
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4944 ± 0.0670
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5660 ± 0.0470
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5624 ± 0.0898
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5384 ± 0.0155
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5295 ± 0.0150
# ----------------------------------------
# Parameters: {'clf__C': 1, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5013 ± 0.0862
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5270 ± 0.0699
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5354 ± 0.0396
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5277 ± 0.1148
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4744 ± 0.0653
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5036 ± 0.0260
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5443 ± 0.0307
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.4883 ± 0.0615
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5417 ± 0.1318
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4901 ± 0.0888
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4813 ± 0.0723
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5648 ± 0.0411
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.4967 ± 0.0655
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.4897 ± 0.0752
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5852 ± 0.0733
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 25, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5521 ± 0.0529
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5782 ± 0.0390
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5315 ± 0.0773
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5341 ± 0.0109
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4608 ± 0.0546
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4562 ± 0.0515
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5840 ± 0.0427
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5560 ± 0.0552
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5154 ± 0.0247
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4830 ± 0.0535
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4969 ± 0.0815
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5510 ± 0.0204
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5320 ± 0.0360
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5601 ± 0.0169
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.4917 ± 0.0768
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 50, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4932 ± 0.0927
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5012 ± 0.0464
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5532 ± 0.0083
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5541 ± 0.0365
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5520 ± 0.0420
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 20, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5194 ± 0.0678
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5251 ± 0.0127
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5341 ± 0.0170
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5202 ± 0.0401
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5742 ± 0.0303
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.5629 ± 0.0414
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.2}
# Mean AUC-ROC: 0.5582 ± 0.0321
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.3}
# Mean AUC-ROC: 0.5463 ± 0.0345
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.4}
# Mean AUC-ROC: 0.5448 ± 0.0379
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.5}
# Mean AUC-ROC: 0.5356 ± 0.0175
# ----------------------------------------
# Parameters: {'clf__C': 10, 'select__k': 100, 'select__n_bootstrap': 100, 'select__threshold': 0.6}
# Mean AUC-ROC: 0.4744 ± 0.0653
# ----------------------------------------
#
# Best Model Summary:
# Best Parameters: {'clf__C': 1, 'select__k': 50, 'select__n_bootstrap': 50, 'select__threshold': 0.6}
# Best Mean AUC-ROC: 0.6093

# %%
print("Evaluating on Training Data")

y_train_pred = best_model.predict(X_train)
if hasattr(best_model, "predict_proba"):
    y_scores_train = best_model.predict_proba(X_train)[:, 1]
elif hasattr(best_model, "decision_function"):
    y_scores_train = best_model.decision_function(X_train)
else:
    y_scores_train = y_train_pred

cm_train = confusion_matrix(y_train, y_train_pred)
tn, fp, fn, tp = cm_train.ravel()

precision = precision_score(y_train, y_train_pred)
recall = recall_score(y_train, y_train_pred)
roc_auc = roc_auc_score(y_train, y_scores_train)

print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"AUC-ROC: {roc_auc:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_train, y_scores_train)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"Train ROC (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Training Data")
plt.legend()
plt.show()
# Out:
# Evaluating on Training Data
# True Positives (TP): 50
# False Positives (FP): 44
# True Negatives (TN): 214
# False Negatives (FN): 8
# Precision: 0.532
# Recall: 0.862
# AUC-ROC: 0.9303

# %%
print("Evaluating on Validation Data")

y_val_pred = best_model.predict(X_val)
if hasattr(best_model, "predict_proba"):
    y_scores_val = best_model.predict_proba(X_val)[:, 1]
elif hasattr(best_model, "decision_function"):
    y_scores_val = best_model.decision_function(X_val)
else:
    y_scores_val = y_val_pred

cm_val = confusion_matrix(y_val, y_val_pred)
tn, fp, fn, tp = cm_val.ravel()

precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_scores_val)

print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"AUC-ROC: {roc_auc:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_val, y_scores_val)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"Validation ROC (AUC = {roc_auc:.2f})", color="orange")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Validation Data")
plt.legend()
plt.show()


# Compute predicted probabilities
if hasattr(best_model, "predict_proba"):
    y_scores_val = best_model.predict_proba(X_val)[:, 1]
elif hasattr(best_model, "decision_function"):
    y_scores_val = best_model.decision_function(X_val)
else:
    raise ValueError("Model does not support probability or decision scores.")

# Set a custom threshold
threshold = 0.535  # lower = more positive predictions
y_val_pred_custom = (y_scores_val >= threshold).astype(int)

# Evaluate
cm_val = confusion_matrix(y_val, y_val_pred_custom)
tn, fp, fn, tp = cm_val.ravel()

precision = precision_score(y_val, y_val_pred_custom)
recall = recall_score(y_val, y_val_pred_custom)
roc_auc = roc_auc_score(y_val, y_scores_val)

print(f"Using threshold = {threshold}")
print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"AUC-ROC: {roc_auc:.4f}")

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np

y_scores = best_model.predict_proba(X_val)[:, 1]
prec, rec, thresholds = precision_recall_curve(y_val, y_scores)
f1s = 2 * (prec * rec) / (prec + rec + 1e-10)
best_f1 = np.max(f1s)
best_thresh = thresholds[np.argmax(f1s)]

print(f"Max F1: {best_f1:.3f} at threshold {best_thresh:.3f}")

# %%
# Make sure y_scores_val are probabilities or decision scores
# (you likely already have this part)
# y_scores_val = best_model.predict_proba(X_val)[:, 1]

# Compute precision, recall, thresholds
precisions, recalls, thresholds = precision_recall_curve(y_val, y_scores)

# Compute F1 for each threshold
f1s = 2 * (precisions * recalls) / (precisions + recalls + 1e-10)

# Find best F1 and threshold
best_idx = np.argmax(f1s)
best_threshold = thresholds[best_idx]
best_f1 = f1s[best_idx]

# Plot
plt.figure(figsize=(7, 5))
plt.plot(thresholds, f1s[:-1], label="F1 Score", color="darkorange")
plt.axvline(best_threshold, color="red", linestyle="--", label=f"Best Threshold = {best_threshold:.3f}")
plt.title("F1 Score vs. Decision Threshold")
plt.xlabel("Decision Threshold")
plt.ylabel("F1 Score")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"Best F1 = {best_f1:.3f} at threshold = {best_threshold:.3f}")

# %%
print("Evaluating on Test Data")

y_test_pred = best_model.predict(X_test)
if hasattr(best_model, "predict_proba"):
    y_scores_test = best_model.predict_proba(X_test)[:, 1]
elif hasattr(best_model, "decision_function"):
    y_scores_test = best_model.decision_function(X_test)
else:
    y_scores_test = y_test_pred

roc_auc_test = roc_auc_score(y_test, y_scores_test)
print(f"AUC-ROC (Test): {roc_auc_test:.4f}")

fpr, tpr, _ = roc_curve(y_test, y_scores_test)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"Test ROC (AUC = {roc_auc_test:.2f})", color="green")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Test Data")
plt.legend()
plt.show()

# %%
# print("Evaluating on Testing Data")

# y_test_pred = best_model.predict(X_test)
# if hasattr(best_model, "predict_proba"):
#     y_scores_test = best_model.predict_proba(X_test)[:, 1]
# elif hasattr(best_model, "decision_function"):
#     y_scores_test = best_model.decision_function(X_test)
# else:
#     y_scores_test = y_test_pred

# cm_test = confusion_matrix(y_test, y_test_pred)
# tn, fp, fn, tp = cm_test.ravel()

# precision = precision_score(y_test, y_test_pred)
# recall = recall_score(y_test, y_test_pred)
# roc_auc = roc_auc_score(y_test, y_scores_test)

# print(f"True Positives (TP): {tp}")
# print(f"False Positives (FP): {fp}")
# print(f"True Negatives (TN): {tn}")
# print(f"False Negatives (FN): {fn}")
# print(f"Precision: {precision:.3f}")
# print(f"Recall: {recall:.3f}")
# print(f"AUC-ROC: {roc_auc:.4f}")

# # ROC Curve
# fpr, tpr, _ = roc_curve(y_test, y_scores_test)
# plt.figure(figsize=(6, 6))
# plt.plot(fpr, tpr, label=f"Testing ROC (AUC = {roc_auc:.2f})", color="orange")
# plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
# plt.xlabel("False Positive Rate")
# plt.ylabel("True Positive Rate")
# plt.title("ROC Curve - Testing Data")
# plt.legend()
# plt.show()
