# %%
import os
import pandas as pd
import joblib
import config
import numpy as np
from scipy import stats
from itertools import combinations
from sklearn.compose import ColumnTransformer

from preprocessing_utils import (
    load_and_split_data,
    MrnaPreprocessorWrapper,
    ClinicalPreprocessorWrapper,
    MutationPreprocessorWrapper,
)

X_train, y_train, X_val, y_val, X_test, y_test, clinical_cols, mrna_cols, mutation_cols = load_and_split_data()

# Create output directory
os.makedirs(config.SPLIT_DATA_DIR, exist_ok=True)

# Save all artifacts in the new folder
joblib.dump(X_train, os.path.join(config.SPLIT_DATA_DIR, "X_train.joblib"))
joblib.dump(y_train, os.path.join(config.SPLIT_DATA_DIR, "y_train.joblib"))
joblib.dump(X_val, os.path.join(config.SPLIT_DATA_DIR, "X_val.joblib"))
joblib.dump(y_val, os.path.join(config.SPLIT_DATA_DIR, "y_val.joblib"))
joblib.dump(X_test, os.path.join(config.SPLIT_DATA_DIR, "X_test.joblib"))
joblib.dump(y_test, os.path.join(config.SPLIT_DATA_DIR, "y_test.joblib"))
joblib.dump(clinical_cols, os.path.join(config.SPLIT_DATA_DIR, "clinical_cols.joblib"))
joblib.dump(mrna_cols, os.path.join(config.SPLIT_DATA_DIR, "mrna_cols.joblib"))
joblib.dump(mutation_cols, os.path.join(config.SPLIT_DATA_DIR, "mutation_cols.joblib"))
print("Done")
# Out:
# loading and splitting data
# loaded clinical
# LOADED ALL
# before split labels PATIENT_ID
# TCGA-2E-A9G8    1.0
# TCGA-4E-A92E    NaN
# TCGA-5B-A90C    1.0
# TCGA-5S-A9Q8    NaN
# TCGA-A5-A0G1    NaN
#                ...
# TCGA-QS-A8F1    NaN
# TCGA-SJ-A6ZI    NaN
# TCGA-SJ-A6ZJ    NaN
# TCGA-SL-A6J9    NaN
# TCGA-SL-A6JA    NaN
# Name: LABEL, Length: 528, dtype: float64
# MRA Hugo_Symbol   100130426  100133144  UBE2Q2P2  HMGB1P1   10431  136542  155060  \
# TCGA-2E-A9G8    -2.4401    -0.0202    0.4928  -1.8662  0.3850     NaN  0.7780
# TCGA-4E-A92E    -2.4401     1.7123    2.3048  -1.1089 -2.4810     NaN  1.0520
# TCGA-5B-A90C    -2.4401     0.6699   -0.3080  -0.0201 -1.5710     NaN -0.4586
# TCGA-5S-A9Q8    -2.4401     0.9029    0.5364  -2.5362 -0.9352     NaN  1.4428
# TCGA-A5-A1OH    -2.4401     0.5542    1.1498  -0.0772 -0.1062     NaN -0.8638
# ...                 ...        ...       ...      ...     ...     ...     ...
# TCGA-FI-A2EW        NaN    -1.6633   -0.2936  -0.0135  0.7372     NaN  0.6898
# TCGA-FI-A2EX        NaN    -0.6706   -0.5520   0.4706  1.6990     NaN -0.4750
# TCGA-FI-A2F4        NaN    -0.3844    0.7558   0.6762 -1.3182     NaN  0.4366
# TCGA-FI-A2F8        NaN    -0.4494   -0.3067   0.8516  0.1886     NaN  0.3108
# TCGA-FI-A2F9        NaN    -0.9687   -0.0085  -1.0104 -1.4244     NaN  0.8842
#
# Hugo_Symbol   RNU12-2P   SSX9P  317712  ...  ZWILCH   ZWINT    ZXDA    ZXDB  \
# TCGA-2E-A9G8   -1.4316 -1.3793     NaN  ...  0.2662  0.4861  0.0461 -0.4127
# TCGA-4E-A92E    0.6479 -1.3793     NaN  ...  0.4397 -0.6784  1.6080  1.0939
# TCGA-5B-A90C   -1.4316 -1.3793     NaN  ...  1.3995  0.5036  0.1134 -0.8295
# TCGA-5S-A9Q8    0.9855 -1.3793     NaN  ... -0.0644 -0.7707 -1.3098 -0.8397
# TCGA-A5-A1OH   -1.4316 -0.7397     NaN  ...  1.5013  0.6452 -0.7222 -0.5913
# ...                ...     ...     ...  ...     ...     ...     ...     ...
# TCGA-FI-A2EW       NaN     NaN     NaN  ... -0.4865  1.7300 -0.3694 -0.7326
# TCGA-FI-A2EX       NaN     NaN     NaN  ...  0.8193  0.6556  0.3692 -0.4448
# TCGA-FI-A2F4       NaN     NaN     NaN  ...  0.7203 -0.0250  1.4779  0.9845
# TCGA-FI-A2F8       NaN     NaN     NaN  ... -0.2248  0.1608 -0.1533  0.1381
# TCGA-FI-A2F9       NaN     NaN     NaN  ... -0.7142 -0.4564  1.4487  1.6106
#
# Hugo_Symbol     ZXDC  ZYG11A  ZYG11B     ZYX   ZZEF1    ZZZ3
# TCGA-2E-A9G8  0.2039  0.9978  0.0843  0.7231 -4.0906  0.0120
# TCGA-4E-A92E  0.3707 -1.1037  0.0381 -0.4606  0.9603  0.8954
# TCGA-5B-A90C  0.3350  0.0791  0.1211 -0.3092 -2.2840  1.4414
# TCGA-5S-A9Q8 -0.3207  0.2388 -1.4490 -1.7162 -0.2543  0.0365
# TCGA-A5-A1OH  1.5926  0.8029  0.0692 -0.5578 -1.1137 -0.0582
# ...              ...     ...     ...     ...     ...     ...
# TCGA-FI-A2EW  1.9490  1.4778  0.5425 -0.3585  0.6357  1.2365
# TCGA-FI-A2EX  0.9751  1.2368  0.6110  0.6633  0.3065 -0.2551
# TCGA-FI-A2F4 -0.2992 -1.1770  0.4742  0.1656  0.9333  0.1805
# TCGA-FI-A2F8  0.6811  0.8511  0.7836  1.4443  0.4544  0.4594
# TCGA-FI-A2F9  2.1182 -0.5343  1.8385  0.1875  0.3533  0.5415
#
# [527 rows x 20531 columns]
# Index(['TCGA-2E-A9G8', 'TCGA-4E-A92E', 'TCGA-5B-A90C', 'TCGA-5S-A9Q8',
#        'TCGA-A5-A0G1', 'TCGA-A5-A0G2', 'TCGA-A5-A0G3', 'TCGA-A5-A0G5',
#        'TCGA-A5-A0G9', 'TCGA-A5-A0GA',
#        ...
#        'TCGA-QF-A5YS', 'TCGA-QF-A5YT', 'TCGA-QS-A5YQ', 'TCGA-QS-A5YR',
#        'TCGA-QS-A744', 'TCGA-QS-A8F1', 'TCGA-SJ-A6ZI', 'TCGA-SJ-A6ZJ',
#        'TCGA-SL-A6J9', 'TCGA-SL-A6JA'],
#       dtype='object', length=512)
# after drop labels TCGA-2E-A9G8    1.0
# TCGA-5B-A90C    1.0
# TCGA-A5-A0G2    0.0
# TCGA-A5-A0G3    1.0
# TCGA-A5-A0G5    0.0
#                ...
# TCGA-JU-AAVI    1.0
# TCGA-K6-A3WQ    1.0
# TCGA-KP-A3W3    1.0
# TCGA-KP-A3W4    1.0
# TCGA-QF-A5YT    0.0
# Name: LABEL, Length: 211, dtype: float64
# on attempt 0
# feature: SUBTYPE
#   categorical p = 0.32510327272913225
# feature: AGE
#   numerical (0-1) p = 0.13795438135570573
#   numerical (0-2) p = 0.5342138212827763
#   numerical (1-2) p = 0.5677752252081372
# feature: RACE
#   categorical p = 0.7513811747334236
# feature: ETHNICITY
#   categorical p = 0.5301679620233736
# feature: ICD_10
#   categorical p = 0.7647507173030844
# feature: ICD_O_3_HISTOLOGY
#   categorical p = 0.0778182371340763
# feature: NEW_TUMOR_EVENT_AFTER_INITIAL_TREATMENT
#   categorical p = 0.9819533393546792
# feature: PATH_T_STAGE
# feature: PATH_N_STAGE
# feature: PATH_M_STAGE
# feature: OS_STATUS
#   categorical p = 0.3825972837838264
# feature: DSS_STATUS
#   categorical p = 0.2335929243764418
# feature: DFS_STATUS
#   categorical p = 0.46164933481255566
# feature: PFS_STATUS
#   categorical p = 0.9800987809120463
# Balanced split achieved after 1 attempts.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 44
#      42 joblib.dump(mrna_cols, os.path.join(config.SPLIT_DATA_DIR, "mrna_cols.joblib"))
#      43 joblib.dump(mutation_cols, os.path.join(config.SPLIT_DATA_DIR, "mutation_cols.joblib"))
# ---> 44 joblib.dump(preprocessor, os.path.join(config.SPLIT_DATA_DIR, "preprocessor.joblib"))
#      45 print("Done")
#
# NameError: name 'preprocessor' is not defined
